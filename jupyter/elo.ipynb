# %% [markdown]
# # Measure performance with ELO & Brier Scores
#
# The motivation behind this post is to discuss the concepts of ELO, apply that in an NBA simulation, and then measure it with Brier Scores, in a end-to-end work flow! Thank you to my teacher @MaxHumber, for inspiring this post.
#
# Resources:
# * https://en.wikipedia.org/wiki/Elo_rating_system
# * https://projects.fivethirtyeight.com/complete-history-of-the-nba/#raptors
# * https://fivethirtyeight.com/features/how-we-calculate-nba-elo-ratings/
# * https://en.wikipedia.org/wiki/Brier_score

# %% [markdown]
# ## Import Libraries

# %%
# data wrangling
import pandas as pd
import numpy as np

# plotting
#import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')

# preprocessing & feature engineering
# from sklearn.preprocessing import StandardScaler, LabelBinarizer, PolynomialFeatures
# from sklearn_pandas import DataFrameMapper, CategoricalImputer, FunctionTransformer
# from sklearn.impute import SimpleImputer
# from sklearn.pipeline import make_pipeline
# from imblearn.over_sampling import SMOTE

# modelling & evaluation
# from sklearn.model_selection import train_test_split
# from sklearn.linear_model import LogisticRegression
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.model_selection import GridSearchCV, cross_val_score
# from sklearn.metrics import roc_auc_score, confusion_matrix, accuracy_score
from sklearn.metrics import accuracy_score

# scientific notation off
np.set_printoptions(suppress=True)
pd.options.display.float_format = '{:.2f}'.format

# suppress warnings
#from sklearn.exceptions import DataConversionWarning
#import warnings
#warnings.filterwarnings(action='ignore', category=DataConversionWarning)
# warnings.filterwarnings(action='ignore', category=FutureWarning)

# %% [markdown]
# # Elo

# %% [markdown]
# ## Introduction

# %% [markdown]
# While I was familiar with the concept of elo given its usage from FiveThirtyEight to measure a basketball team's strength, relative to its peers, I was surprised to find out it was actually derived from chess!
#
# > The Elo rating system, is a method for calculating the relative skill levels of players in zero-sum games such as chess. It is named after its creator Arpad Elo, a Hungarian-American physics professor (Source: Wikipedia).
#
# Over the years, you can see it's extension and adoption to a wide range of use cases, including:
# * Video games (CounterStrike, League of Legends)
# * Sports (NBA, football, baseball)
#
# Needless to say, it's a very popular framework! Essentially, the idea is that if you a play stronger opponent and win, you should be rewarded more, than if you play lesser opponents and win, and vice versa, in a zero-sum-game paradigm. This argument intuitively makes sense.

# %% [markdown]
# ## Define Elo Model

# %% [markdown]
# (1) The expected probability of winning of team A follows the logistic curve.
#
# ![image.png](images/logistic_curve.png)
#
# * Note the curve's maximum value is 1
# * This is a common sigmoid curve (prob winning approaches 1 and 0, asymptotically)
#
# (2) The parameters in this model:
# * Ra - rating of team A
# * rb - rating of team B
# * g, the logistic growth rate / steepness of curve
#
# Interpretation of g:
# Given g = 400. For each 400 rating points of advantage over the opponent, the expected probability is 10x in comparison to opponent's expected score (assuming log 10 base) Said another way, a higher g, will require a greater delta between winner and loser elo to impact the probability. For the NBA, we will leave this at 400, the same as Chess.
#
# * k-factor - the adjustment per game based on win or loss, to reward under performance and reward over performance. There needs to be a level of stickiness, as you shouldn't lose all of your elo points with one game, and the score retains some memory.
#
#     * According to FiveThirtyEight, and empirical evidence, the optimal K for the NBA to be 20. it’s in the same range as the K used for NFL and international soccer elo ratings even though the NBA plays far more games than those sports. It’s much higher than the optimal K for baseball. It suggests that you should to give relatively high weight to an NBA team’s recent performance. For reference, it's typically 16 for master chess players.
#
# * Baseline elo score - we will use 1500 for the NBA. This is the long term average elo score.
#
# (3) Equation to update a team's elo score after each game:
#
#     * ![image.png](images/update_score.png)
#     * Previous score + k-factor * (P(a) - Ea)
#
# * Create a table to summarize our parameters

# %%
class EloTracker:
    # start baseline elo at 1500
    # EloTracker takes data in the form of a dictionary or a list and shapes it into a dictionary 
    # This is how we're tracking our elo scores
    def __init__(self, data, start=1500):
        if isinstance(data, dict):
            self.data = data
        if isinstance(data, list):
            self.data = {i: start for i in data}
    
    # Expected probability of winning
    # Pr(A) = 1 / (10^(-ELODIFF/400) + 1)
    def prob(self, winner, loser):
        winner_elo, loser_elo = self.data[winner], self.data[loser]
        # add home court advantage
        expected_winner = 1 / ( 1 + 10**((loser_elo - winner_elo)/400) )
        expected_loser = 1 - expected_winner
        return expected_winner, expected_loser

    # set k=20 for NBA
    # remember, winner has probability of 1 and loser has probability of 0
    def update(self, winner, loser, k=20):
        expected_winner, expected_loser = self.prob(winner, loser)
        self.data[winner] = round(self.data[winner] + k*(1 - expected_winner))
        self.data[loser] = round(self.data[loser] + k*(0 - expected_loser))
        return self.data

    def __repr__(self):
        return f'EloTracker({self.data})'

# %%
# instantiate all teams at 1500 elo
teams = ['Toronto', 'Boston', 'Cleveland']
elo = EloTracker(teams)
elo.data
# Out:
# {'Toronto': 1500, 'Boston': 1500, 'Cleveland': 1500}

# %%
# By definition, teams with the same elo are equally likely to win,
# with home court advantage Toronto is the *slight* favourite
elo.prob('Toronto', 'Boston')
# Out:
# (0.5, 0.5)

# %%
# Toronto beats Boston
# Update elo; Toronto gained 16 elo and Boston lost 16
elo.update('Toronto', 'Boston')
# Out:
# {'Toronto': 1516, 'Boston': 1484, 'Cleveland': 1500}

# %%
# end of season, let's assume these elo scores
teams = {'Toronto': 1750, 'Boston': 1500, 'Cleveland': 1250}
elo = EloTracker(teams)
elo.data
toronto_elo_before = elo.data["Toronto"]
elo.update("Toronto", "Cleveland")
toronto_elo_after = elo.data["Toronto"]

print(f' Toronto gained {toronto_elo_after - toronto_elo_before} elo points')
# Because Toronto won against a worst team, they only gained 2 elo points.
# Out:
#  Toronto gained 2 elo points

# %%
# what if Toronto lost?
teams = {'Toronto': 1750, 'Boston': 1500, 'Cleveland': 1250}
elo = EloTracker(teams)
elo.data
toronto_elo_before = elo.data["Toronto"]
elo.update("Cleveland","Toronto")
toronto_elo_after = elo.data["Toronto"]

print(f' Toronto gained {toronto_elo_after - toronto_elo_before} elo points')
# Because Toronto lost to a worse team, they lost 30 elo points! They were expected to win!
# Out:
#  Toronto gained -30 elo points

# %% [markdown]
# # Wrangle Game Data to Season Data

# %%
# for each game, loop through and accumulate the points for each team
# full=False, means only return points, without dates
def reproduce_points(df, full=False):
    teams = sorted(list(df.home.unique()))
    points = {team: 0 for team in teams}
    points_and_dates = {}
    for i, row in df.iterrows():
        if row.extra_time and row.goals_home > row.goals_visitor:
            points[row.home] += 2
            points[row.visitor] += 1
        elif row.extra_time and row.goals_home < row.goals_visitor:
            points[row.home] += 1
            points[row.visitor] += 2
        elif row.goals_home > row.goals_visitor:
            points[row.home] += 2
        else:
            points[row.visitor] += 2
        # keep a running total of the points at each given row.date
        points_and_dates[row.date] = points.copy()
    if full:
        return points_and_dates
    else:
        return points

def points_to_dataframe(points):
    # take dataframe, reset index and re name index as team from 0 to ...
    # try to understand this later
    # creates points for each day, there will be days where the points do not change
    df = (
        pd.DataFrame(points)
        .reset_index()
        .rename(columns={'index':'team'}))
    
    start = pd.Timestamp(df.columns[1]) - pd.Timedelta(days=1)
    df[start.strftime('%Y-%m-%d')] = 0
    
    df = pd.melt(
        pd.DataFrame(df),
        id_vars=['team'],
        var_name='date',
        value_name='points')
    
    df['date'] = df['date'].apply(pd.to_datetime)
    
    df = df.sort_values(['date', 'team'])
    
    df['points_before'] = df.groupby('team')['points'].shift(1)
    df['points_before'] = df['points_before'].fillna(0).astype(int)
    df['date'] = df['date'].dt.strftime('%Y-%m-%d')
    return df


def games_to_points(df):
    points = reproduce_points(games, full=True)
    points = points_to_dataframe(points)
    return points

# retreive points at a given point in time
def retrieve_points(team, date):
    return points.query(
        f'team == "{team}" & date == "{date}"'
    )['points_before'].values[0]

def predict_based_on_points(home, away, date):
    points_home = retrieve_points(home, date)
    points_away = retrieve_points(away, date)
    if points_home == points_away:
        return home
    elif points_home > points_away:
        return home
    else:
        return away

# %%
# games = download_data('2017')
games = pd.read_csv('./data/nhl_2018-2019.csv')
games.head()
# Out:
#          date                 home             visitor  goals_home  \
# 0  2018-10-03      San Jose Sharks       Anaheim Ducks         2.0
# 1  2018-10-03  Toronto Maple Leafs  Montreal Canadiens         3.0
# 2  2018-10-03    Vancouver Canucks      Calgary Flames         5.0
# 3  2018-10-03  Washington Capitals       Boston Bruins         7.0
# 4  2018-10-04       Buffalo Sabres       Boston Bruins         0.0
#
#    goals_visitor  extra_time
# 0            5.0           0
# 1            2.0           1
# 2            2.0           0
# 3            0.0           0
# 4            4.0           0

# %%
points = games_to_points(games)
points.tail()
# Out:
#                       team        date  points  points_before
# 5358   Toronto Maple Leafs  2019-04-02      99             99
# 5359     Vancouver Canucks  2019-04-02      80             78
# 5360  Vegas Golden Knights  2019-04-02      93             93
# 5361   Washington Capitals  2019-04-02     102            102
# 5362         Winnipeg Jets  2019-04-02      96             96

# %%
# establish baselines
df = games.copy()
df['winner'] = np.where(df.goals_home > df.goals_visitor, df.home, df.visitor)

# %%
# baseline model 1
y = df['winner'] # true
y_hat = df['home'] # predict winner based on home team winning
accuracy_score(y, y_hat)
# Out:
# 0.537156704361874

# %%
# baseline model 2
df['points'] = df.apply(lambda row:
    predict_based_on_points(row.home, row.visitor, row.date), axis=1)
y = df['winner'] # true 
y_hat = df['points'] # predict winner based on higher points
accuracy_score(y, y_hat)
# Out:
# 0.5379644588045234

# %%
# Are we able to create a model with elo that is more predictive?

# %% [markdown]
# # Elo Model

# %%
games.head()
# Out:
#          date                 home             visitor  goals_home  \
# 0  2018-10-03      San Jose Sharks       Anaheim Ducks         2.0
# 1  2018-10-03  Toronto Maple Leafs  Montreal Canadiens         3.0
# 2  2018-10-03    Vancouver Canucks      Calgary Flames         5.0
# 3  2018-10-03  Washington Capitals       Boston Bruins         7.0
# 4  2018-10-04       Buffalo Sabres       Boston Bruins         0.0
#
#    goals_visitor  extra_time
# 0            5.0           0
# 1            2.0           1
# 2            2.0           0
# 3            0.0           0
# 4            4.0           0

# %%
games['winner'] = np.where(games.goals_home > games.goals_visitor, games.home, games.visitor)
df = games[['date', 'home', 'visitor', 'winner']]
df.head()
# Out:
#          date                 home             visitor               winner
# 0  2018-10-03      San Jose Sharks       Anaheim Ducks        Anaheim Ducks
# 1  2018-10-03  Toronto Maple Leafs  Montreal Canadiens  Toronto Maple Leafs
# 2  2018-10-03    Vancouver Canucks      Calgary Flames    Vancouver Canucks
# 3  2018-10-03  Washington Capitals       Boston Bruins  Washington Capitals
# 4  2018-10-04       Buffalo Sabres       Boston Bruins        Boston Bruins

# %%
teams = df['winner'].unique().tolist()
elo = EloTracker(sorted(teams))

# %%
elo.data
# Out:
# {'Anaheim Ducks': 1500,
#  'Arizona Coyotes': 1500,
#  'Boston Bruins': 1500,
#  'Buffalo Sabres': 1500,
#  'Calgary Flames': 1500,
#  'Carolina Hurricanes': 1500,
#  'Chicago Blackhawks': 1500,
#  'Colorado Avalanche': 1500,
#  'Columbus Blue Jackets': 1500,
#  'Dallas Stars': 1500,
#  'Detroit Red Wings': 1500,
#  'Edmonton Oilers': 1500,
#  'Florida Panthers': 1500,
#  'Los Angeles Kings': 1500,
#  'Minnesota Wild': 1500,
#  'Montreal Canadiens': 1500,
#  'Nashville Predators': 1500,
#  'New Jersey Devils': 1500,
#  'New York Islanders': 1500,
#  'New York Rangers': 1500,
#  'Ottawa Senators': 1500,
#  'Philadelphia Flyers': 1500,
#  'Pittsburgh Penguins': 1500,
#  'San Jose Sharks': 1500,
#  'St. Louis Blues': 1500,
#  'Tampa Bay Lightning': 1500,
#  'Toronto Maple Leafs': 1500,
#  'Vancouver Canucks': 1500,
#  'Vegas Golden Knights': 1500,
#  'Washington Capitals': 1500,
#  'Winnipeg Jets': 1500}

# %%
elo_by_date = {}
for i, row in df.iterrows():
    if row.winner == row.home:
        elo.update(row.home, row.visitor, k=20)
    else:
        elo.update(row.visitor, row.home, k=20)
    elo_by_date[row.date] = elo.data.copy()

elo_by_date
# Out:
# {'2018-10-03': {'Anaheim Ducks': 1510,
#   'Arizona Coyotes': 1500,
#   'Boston Bruins': 1490,
#   'Buffalo Sabres': 1500,
#   'Calgary Flames': 1490,
#   'Carolina Hurricanes': 1500,
#   'Chicago Blackhawks': 1500,
#   'Colorado Avalanche': 1500,
#   'Columbus Blue Jackets': 1500,
#   'Dallas Stars': 1500,
#   'Detroit Red Wings': 1500,
#   'Edmonton Oilers': 1500,
#   'Florida Panthers': 1500,
#   'Los Angeles Kings': 1500,
#   'Minnesota Wild': 1500,
#   'Montreal Canadiens': 1490,
#   'Nashville Predators': 1500,
#   'New Jersey Devils': 1500,
#   'New York Islanders': 1500,
#   'New York Rangers': 1500,
#   'Ottawa Senators': 1500,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1500,
#   'San Jose Sharks': 1490,
#   'St. Louis Blues': 1500,
#   'Tampa Bay Lightning': 1500,
#   'Toronto Maple Leafs': 1510,
#   'Vancouver Canucks': 1510,
#   'Vegas Golden Knights': 1500,
#   'Washington Capitals': 1510,
#   'Winnipeg Jets': 1500},
#  '2018-10-04': {'Anaheim Ducks': 1510,
#   'Arizona Coyotes': 1490,
#   'Boston Bruins': 1500,
#   'Buffalo Sabres': 1490,
#   'Calgary Flames': 1490,
#   'Carolina Hurricanes': 1490,
#   'Chicago Blackhawks': 1510,
#   'Colorado Avalanche': 1510,
#   'Columbus Blue Jackets': 1510,
#   'Dallas Stars': 1510,
#   'Detroit Red Wings': 1490,
#   'Edmonton Oilers': 1500,
#   'Florida Panthers': 1500,
#   'Los Angeles Kings': 1500,
#   'Minnesota Wild': 1490,
#   'Montreal Canadiens': 1490,
#   'Nashville Predators': 1510,
#   'New Jersey Devils': 1500,
#   'New York Islanders': 1510,
#   'New York Rangers': 1490,
#   'Ottawa Senators': 1490,
#   'Philadelphia Flyers': 1510,
#   'Pittsburgh Penguins': 1510,
#   'San Jose Sharks': 1490,
#   'St. Louis Blues': 1490,
#   'Tampa Bay Lightning': 1500,
#   'Toronto Maple Leafs': 1510,
#   'Vancouver Canucks': 1510,
#   'Vegas Golden Knights': 1490,
#   'Washington Capitals': 1500,
#   'Winnipeg Jets': 1510},
#  '2018-10-05': {'Anaheim Ducks': 1510,
#   'Arizona Coyotes': 1490,
#   'Boston Bruins': 1500,
#   'Buffalo Sabres': 1490,
#   'Calgary Flames': 1490,
#   'Carolina Hurricanes': 1501,
#   'Chicago Blackhawks': 1510,
#   'Colorado Avalanche': 1510,
#   'Columbus Blue Jackets': 1499,
#   'Dallas Stars': 1510,
#   'Detroit Red Wings': 1490,
#   'Edmonton Oilers': 1500,
#   'Florida Panthers': 1500,
#   'Los Angeles Kings': 1490,
#   'Minnesota Wild': 1490,
#   'Montreal Canadiens': 1490,
#   'Nashville Predators': 1510,
#   'New Jersey Devils': 1500,
#   'New York Islanders': 1510,
#   'New York Rangers': 1490,
#   'Ottawa Senators': 1490,
#   'Philadelphia Flyers': 1510,
#   'Pittsburgh Penguins': 1510,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1490,
#   'Tampa Bay Lightning': 1500,
#   'Toronto Maple Leafs': 1510,
#   'Vancouver Canucks': 1510,
#   'Vegas Golden Knights': 1490,
#   'Washington Capitals': 1500,
#   'Winnipeg Jets': 1510},
#  '2018-10-06': {'Anaheim Ducks': 1519,
#   'Arizona Coyotes': 1481,
#   'Boston Bruins': 1500,
#   'Buffalo Sabres': 1500,
#   'Calgary Flames': 1501,
#   'Carolina Hurricanes': 1501,
#   'Chicago Blackhawks': 1519,
#   'Colorado Avalanche': 1520,
#   'Columbus Blue Jackets': 1499,
#   'Dallas Stars': 1520,
#   'Detroit Red Wings': 1490,
#   'Edmonton Oilers': 1490,
#   'Florida Panthers': 1490,
#   'Los Angeles Kings': 1490,
#   'Minnesota Wild': 1480,
#   'Montreal Canadiens': 1501,
#   'Nashville Predators': 1520,
#   'New Jersey Devils': 1510,
#   'New York Islanders': 1500,
#   'New York Rangers': 1480,
#   'Ottawa Senators': 1501,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1499,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1499,
#   'Vancouver Canucks': 1499,
#   'Vegas Golden Knights': 1500,
#   'Washington Capitals': 1500,
#   'Winnipeg Jets': 1500},
#  '2018-10-07': {'Anaheim Ducks': 1519,
#   'Arizona Coyotes': 1481,
#   'Boston Bruins': 1500,
#   'Buffalo Sabres': 1500,
#   'Calgary Flames': 1501,
#   'Carolina Hurricanes': 1510,
#   'Chicago Blackhawks': 1508,
#   'Colorado Avalanche': 1520,
#   'Columbus Blue Jackets': 1499,
#   'Dallas Stars': 1520,
#   'Detroit Red Wings': 1480,
#   'Edmonton Oilers': 1490,
#   'Florida Panthers': 1490,
#   'Los Angeles Kings': 1500,
#   'Minnesota Wild': 1480,
#   'Montreal Canadiens': 1501,
#   'Nashville Predators': 1520,
#   'New Jersey Devils': 1510,
#   'New York Islanders': 1500,
#   'New York Rangers': 1471,
#   'Ottawa Senators': 1501,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1499,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1510,
#   'Vancouver Canucks': 1499,
#   'Vegas Golden Knights': 1500,
#   'Washington Capitals': 1500,
#   'Winnipeg Jets': 1500},
#  '2018-10-08': {'Anaheim Ducks': 1528,
#   'Arizona Coyotes': 1481,
#   'Boston Bruins': 1510,
#   'Buffalo Sabres': 1510,
#   'Calgary Flames': 1501,
#   'Carolina Hurricanes': 1510,
#   'Chicago Blackhawks': 1508,
#   'Colorado Avalanche': 1520,
#   'Columbus Blue Jackets': 1499,
#   'Dallas Stars': 1520,
#   'Detroit Red Wings': 1471,
#   'Edmonton Oilers': 1490,
#   'Florida Panthers': 1490,
#   'Los Angeles Kings': 1500,
#   'Minnesota Wild': 1480,
#   'Montreal Canadiens': 1501,
#   'Nashville Predators': 1520,
#   'New Jersey Devils': 1510,
#   'New York Islanders': 1510,
#   'New York Rangers': 1471,
#   'Ottawa Senators': 1491,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1499,
#   'San Jose Sharks': 1490,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1510,
#   'Vancouver Canucks': 1499,
#   'Vegas Golden Knights': 1490,
#   'Washington Capitals': 1500,
#   'Winnipeg Jets': 1500},
#  '2018-10-09': {'Anaheim Ducks': 1528,
#   'Arizona Coyotes': 1481,
#   'Boston Bruins': 1510,
#   'Buffalo Sabres': 1510,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1520,
#   'Chicago Blackhawks': 1508,
#   'Colorado Avalanche': 1509,
#   'Columbus Blue Jackets': 1510,
#   'Dallas Stars': 1510,
#   'Detroit Red Wings': 1471,
#   'Edmonton Oilers': 1490,
#   'Florida Panthers': 1490,
#   'Los Angeles Kings': 1490,
#   'Minnesota Wild': 1480,
#   'Montreal Canadiens': 1501,
#   'Nashville Predators': 1509,
#   'New Jersey Devils': 1510,
#   'New York Islanders': 1510,
#   'New York Rangers': 1471,
#   'Ottawa Senators': 1491,
#   'Philadelphia Flyers': 1490,
#   'Pittsburgh Penguins': 1499,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1520,
#   'Vancouver Canucks': 1489,
#   'Vegas Golden Knights': 1490,
#   'Washington Capitals': 1500,
#   'Winnipeg Jets': 1510},
#  '2018-10-10': {'Anaheim Ducks': 1517,
#   'Arizona Coyotes': 1492,
#   'Boston Bruins': 1510,
#   'Buffalo Sabres': 1510,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1520,
#   'Chicago Blackhawks': 1508,
#   'Colorado Avalanche': 1509,
#   'Columbus Blue Jackets': 1510,
#   'Dallas Stars': 1510,
#   'Detroit Red Wings': 1471,
#   'Edmonton Oilers': 1490,
#   'Florida Panthers': 1490,
#   'Los Angeles Kings': 1490,
#   'Minnesota Wild': 1480,
#   'Montreal Canadiens': 1501,
#   'Nashville Predators': 1509,
#   'New Jersey Devils': 1510,
#   'New York Islanders': 1510,
#   'New York Rangers': 1471,
#   'Ottawa Senators': 1481,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1499,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1520,
#   'Vancouver Canucks': 1489,
#   'Vegas Golden Knights': 1480,
#   'Washington Capitals': 1510,
#   'Winnipeg Jets': 1510},
#  '2018-10-11': {'Anaheim Ducks': 1517,
#   'Arizona Coyotes': 1492,
#   'Boston Bruins': 1519,
#   'Buffalo Sabres': 1500,
#   'Calgary Flames': 1501,
#   'Carolina Hurricanes': 1520,
#   'Chicago Blackhawks': 1497,
#   'Colorado Avalanche': 1519,
#   'Columbus Blue Jackets': 1519,
#   'Dallas Stars': 1510,
#   'Detroit Red Wings': 1462,
#   'Edmonton Oilers': 1481,
#   'Florida Panthers': 1481,
#   'Los Angeles Kings': 1500,
#   'Minnesota Wild': 1491,
#   'Montreal Canadiens': 1491,
#   'Nashville Predators': 1519,
#   'New Jersey Devils': 1520,
#   'New York Islanders': 1510,
#   'New York Rangers': 1482,
#   'Ottawa Senators': 1481,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1508,
#   'San Jose Sharks': 1489,
#   'St. Louis Blues': 1492,
#   'Tampa Bay Lightning': 1499,
#   'Toronto Maple Leafs': 1529,
#   'Vancouver Canucks': 1500,
#   'Vegas Golden Knights': 1471,
#   'Washington Capitals': 1500,
#   'Winnipeg Jets': 1500},
#  '2018-10-13': {'Anaheim Ducks': 1507,
#   'Arizona Coyotes': 1482,
#   'Boston Bruins': 1527,
#   'Buffalo Sabres': 1510,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1529,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1508,
#   'Columbus Blue Jackets': 1508,
#   'Dallas Stars': 1520,
#   'Detroit Red Wings': 1454,
#   'Edmonton Oilers': 1491,
#   'Florida Panthers': 1472,
#   'Los Angeles Kings': 1489,
#   'Minnesota Wild': 1482,
#   'Montreal Canadiens': 1501,
#   'Nashville Predators': 1529,
#   'New Jersey Devils': 1520,
#   'New York Islanders': 1500,
#   'New York Rangers': 1472,
#   'Ottawa Senators': 1492,
#   'Philadelphia Flyers': 1489,
#   'Pittsburgh Penguins': 1498,
#   'San Jose Sharks': 1489,
#   'St. Louis Blues': 1482,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1538,
#   'Vancouver Canucks': 1509,
#   'Vegas Golden Knights': 1482,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1500},
#  '2018-10-14': {'Anaheim Ducks': 1516,
#   'Arizona Coyotes': 1482,
#   'Boston Bruins': 1527,
#   'Buffalo Sabres': 1510,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1518,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1508,
#   'Columbus Blue Jackets': 1508,
#   'Dallas Stars': 1520,
#   'Detroit Red Wings': 1454,
#   'Edmonton Oilers': 1491,
#   'Florida Panthers': 1472,
#   'Los Angeles Kings': 1489,
#   'Minnesota Wild': 1482,
#   'Montreal Canadiens': 1501,
#   'Nashville Predators': 1529,
#   'New Jersey Devils': 1529,
#   'New York Islanders': 1500,
#   'New York Rangers': 1472,
#   'Ottawa Senators': 1492,
#   'Philadelphia Flyers': 1489,
#   'Pittsburgh Penguins': 1498,
#   'San Jose Sharks': 1480,
#   'St. Louis Blues': 1473,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1538,
#   'Vancouver Canucks': 1509,
#   'Vegas Golden Knights': 1482,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1511},
#  '2018-10-15': {'Anaheim Ducks': 1516,
#   'Arizona Coyotes': 1482,
#   'Boston Bruins': 1527,
#   'Buffalo Sabres': 1510,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1518,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1508,
#   'Columbus Blue Jackets': 1508,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1445,
#   'Edmonton Oilers': 1491,
#   'Florida Panthers': 1472,
#   'Los Angeles Kings': 1480,
#   'Minnesota Wild': 1473,
#   'Montreal Canadiens': 1510,
#   'Nashville Predators': 1538,
#   'New Jersey Devils': 1529,
#   'New York Islanders': 1500,
#   'New York Rangers': 1472,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1489,
#   'Pittsburgh Penguins': 1498,
#   'San Jose Sharks': 1480,
#   'St. Louis Blues': 1473,
#   'Tampa Bay Lightning': 1510,
#   'Toronto Maple Leafs': 1547,
#   'Vancouver Canucks': 1509,
#   'Vegas Golden Knights': 1482,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1511},
#  '2018-10-16': {'Anaheim Ducks': 1516,
#   'Arizona Coyotes': 1472,
#   'Boston Bruins': 1527,
#   'Buffalo Sabres': 1499,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1508,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1497,
#   'Columbus Blue Jackets': 1508,
#   'Dallas Stars': 1500,
#   'Detroit Red Wings': 1445,
#   'Edmonton Oilers': 1502,
#   'Florida Panthers': 1462,
#   'Los Angeles Kings': 1480,
#   'Minnesota Wild': 1483,
#   'Montreal Canadiens': 1510,
#   'Nashville Predators': 1538,
#   'New Jersey Devils': 1538,
#   'New York Islanders': 1500,
#   'New York Rangers': 1483,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1499,
#   'Pittsburgh Penguins': 1488,
#   'San Jose Sharks': 1480,
#   'St. Louis Blues': 1473,
#   'Tampa Bay Lightning': 1520,
#   'Toronto Maple Leafs': 1547,
#   'Vancouver Canucks': 1519,
#   'Vegas Golden Knights': 1493,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1500},
#  '2018-10-17': {'Anaheim Ducks': 1526,
#   'Arizona Coyotes': 1472,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1499,
#   'Calgary Flames': 1522,
#   'Carolina Hurricanes': 1508,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1497,
#   'Columbus Blue Jackets': 1508,
#   'Dallas Stars': 1500,
#   'Detroit Red Wings': 1445,
#   'Edmonton Oilers': 1502,
#   'Florida Panthers': 1462,
#   'Los Angeles Kings': 1480,
#   'Minnesota Wild': 1483,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1538,
#   'New Jersey Devils': 1538,
#   'New York Islanders': 1490,
#   'New York Rangers': 1473,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1499,
#   'Pittsburgh Penguins': 1488,
#   'San Jose Sharks': 1480,
#   'St. Louis Blues': 1464,
#   'Tampa Bay Lightning': 1520,
#   'Toronto Maple Leafs': 1547,
#   'Vancouver Canucks': 1519,
#   'Vegas Golden Knights': 1493,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1500},
#  '2018-10-18': {'Anaheim Ducks': 1526,
#   'Arizona Coyotes': 1483,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1488,
#   'Calgary Flames': 1522,
#   'Carolina Hurricanes': 1508,
#   'Chicago Blackhawks': 1496,
#   'Colorado Avalanche': 1508,
#   'Columbus Blue Jackets': 1518,
#   'Dallas Stars': 1500,
#   'Detroit Red Wings': 1437,
#   'Edmonton Oilers': 1512,
#   'Florida Panthers': 1462,
#   'Los Angeles Kings': 1470,
#   'Minnesota Wild': 1483,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1538,
#   'New Jersey Devils': 1527,
#   'New York Islanders': 1500,
#   'New York Rangers': 1473,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1489,
#   'Pittsburgh Penguins': 1500,
#   'San Jose Sharks': 1491,
#   'St. Louis Blues': 1464,
#   'Tampa Bay Lightning': 1528,
#   'Toronto Maple Leafs': 1535,
#   'Vancouver Canucks': 1508,
#   'Vegas Golden Knights': 1493,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1511},
#  '2018-10-19': {'Anaheim Ducks': 1526,
#   'Arizona Coyotes': 1483,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1488,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1508,
#   'Chicago Blackhawks': 1496,
#   'Colorado Avalanche': 1508,
#   'Columbus Blue Jackets': 1518,
#   'Dallas Stars': 1490,
#   'Detroit Red Wings': 1437,
#   'Edmonton Oilers': 1512,
#   'Florida Panthers': 1473,
#   'Los Angeles Kings': 1470,
#   'Minnesota Wild': 1493,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1548,
#   'New Jersey Devils': 1527,
#   'New York Islanders': 1500,
#   'New York Rangers': 1473,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1489,
#   'Pittsburgh Penguins': 1500,
#   'San Jose Sharks': 1491,
#   'St. Louis Blues': 1464,
#   'Tampa Bay Lightning': 1528,
#   'Toronto Maple Leafs': 1535,
#   'Vancouver Canucks': 1508,
#   'Vegas Golden Knights': 1493,
#   'Washington Capitals': 1490,
#   'Winnipeg Jets': 1511},
#  '2018-10-20': {'Anaheim Ducks': 1515,
#   'Arizona Coyotes': 1474,
#   'Boston Bruins': 1497,
#   'Buffalo Sabres': 1497,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1498,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1518,
#   'Columbus Blue Jackets': 1507,
#   'Dallas Stars': 1490,
#   'Detroit Red Wings': 1448,
#   'Edmonton Oilers': 1503,
#   'Florida Panthers': 1462,
#   'Los Angeles Kings': 1461,
#   'Minnesota Wild': 1504,
#   'Montreal Canadiens': 1509,
#   'Nashville Predators': 1557,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1490,
#   'New York Rangers': 1473,
#   'Ottawa Senators': 1513,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1500,
#   'San Jose Sharks': 1501,
#   'St. Louis Blues': 1476,
#   'Tampa Bay Lightning': 1517,
#   'Toronto Maple Leafs': 1523,
#   'Vancouver Canucks': 1518,
#   'Vegas Golden Knights': 1504,
#   'Washington Capitals': 1490,
#   'Winnipeg Jets': 1520},
#  '2018-10-21': {'Anaheim Ducks': 1504,
#   'Arizona Coyotes': 1474,
#   'Boston Bruins': 1497,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1521,
#   'Carolina Hurricanes': 1498,
#   'Chicago Blackhawks': 1497,
#   'Colorado Avalanche': 1518,
#   'Columbus Blue Jackets': 1507,
#   'Dallas Stars': 1490,
#   'Detroit Red Wings': 1448,
#   'Edmonton Oilers': 1503,
#   'Florida Panthers': 1462,
#   'Los Angeles Kings': 1461,
#   'Minnesota Wild': 1504,
#   'Montreal Canadiens': 1509,
#   'Nashville Predators': 1557,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1490,
#   'New York Rangers': 1464,
#   'Ottawa Senators': 1513,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1500,
#   'San Jose Sharks': 1501,
#   'St. Louis Blues': 1476,
#   'Tampa Bay Lightning': 1527,
#   'Toronto Maple Leafs': 1523,
#   'Vancouver Canucks': 1518,
#   'Vegas Golden Knights': 1504,
#   'Washington Capitals': 1490,
#   'Winnipeg Jets': 1520},
#  '2018-10-22': {'Anaheim Ducks': 1504,
#   'Arizona Coyotes': 1474,
#   'Boston Bruins': 1497,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1521,
#   'Carolina Hurricanes': 1507,
#   'Chicago Blackhawks': 1497,
#   'Colorado Avalanche': 1527,
#   'Columbus Blue Jackets': 1507,
#   'Dallas Stars': 1490,
#   'Detroit Red Wings': 1439,
#   'Edmonton Oilers': 1503,
#   'Florida Panthers': 1462,
#   'Los Angeles Kings': 1461,
#   'Minnesota Wild': 1504,
#   'Montreal Canadiens': 1509,
#   'Nashville Predators': 1557,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1490,
#   'New York Rangers': 1464,
#   'Ottawa Senators': 1513,
#   'Philadelphia Flyers': 1491,
#   'Pittsburgh Penguins': 1500,
#   'San Jose Sharks': 1501,
#   'St. Louis Blues': 1467,
#   'Tampa Bay Lightning': 1527,
#   'Toronto Maple Leafs': 1523,
#   'Vancouver Canucks': 1507,
#   'Vegas Golden Knights': 1504,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1529},
#  '2018-10-23': {'Anaheim Ducks': 1494,
#   'Arizona Coyotes': 1485,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1511,
#   'Carolina Hurricanes': 1507,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1527,
#   'Columbus Blue Jackets': 1496,
#   'Dallas Stars': 1499,
#   'Detroit Red Wings': 1439,
#   'Edmonton Oilers': 1493,
#   'Florida Panthers': 1452,
#   'Los Angeles Kings': 1452,
#   'Minnesota Wild': 1504,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1545,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1490,
#   'New York Rangers': 1474,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1491,
#   'Pittsburgh Penguins': 1510,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1467,
#   'Tampa Bay Lightning': 1527,
#   'Toronto Maple Leafs': 1523,
#   'Vancouver Canucks': 1507,
#   'Vegas Golden Knights': 1504,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1529},
#  '2018-10-24': {'Anaheim Ducks': 1494,
#   'Arizona Coyotes': 1485,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1511,
#   'Carolina Hurricanes': 1507,
#   'Chicago Blackhawks': 1507,
#   'Colorado Avalanche': 1517,
#   'Columbus Blue Jackets': 1496,
#   'Dallas Stars': 1499,
#   'Detroit Red Wings': 1439,
#   'Edmonton Oilers': 1493,
#   'Florida Panthers': 1463,
#   'Los Angeles Kings': 1452,
#   'Minnesota Wild': 1504,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1545,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1479,
#   'New York Rangers': 1474,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1491,
#   'Pittsburgh Penguins': 1510,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1467,
#   'Tampa Bay Lightning': 1537,
#   'Toronto Maple Leafs': 1533,
#   'Vancouver Canucks': 1517,
#   'Vegas Golden Knights': 1494,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1519},
#  '2018-10-25': {'Anaheim Ducks': 1484,
#   'Arizona Coyotes': 1496,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1518,
#   'Calgary Flames': 1501,
#   'Carolina Hurricanes': 1507,
#   'Chicago Blackhawks': 1516,
#   'Colorado Avalanche': 1517,
#   'Columbus Blue Jackets': 1505,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1439,
#   'Edmonton Oilers': 1503,
#   'Florida Panthers': 1463,
#   'Los Angeles Kings': 1443,
#   'Minnesota Wild': 1513,
#   'Montreal Canadiens': 1509,
#   'Nashville Predators': 1554,
#   'New Jersey Devils': 1507,
#   'New York Islanders': 1479,
#   'New York Rangers': 1465,
#   'Ottawa Senators': 1503,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1520,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1458,
#   'Tampa Bay Lightning': 1537,
#   'Toronto Maple Leafs': 1533,
#   'Vancouver Canucks': 1506,
#   'Vegas Golden Knights': 1494,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1519},
#  '2018-10-26': {'Anaheim Ducks': 1484,
#   'Arizona Coyotes': 1496,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1518,
#   'Calgary Flames': 1501,
#   'Carolina Hurricanes': 1517,
#   'Chicago Blackhawks': 1516,
#   'Colorado Avalanche': 1527,
#   'Columbus Blue Jackets': 1505,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1431,
#   'Edmonton Oilers': 1503,
#   'Florida Panthers': 1463,
#   'Los Angeles Kings': 1443,
#   'Minnesota Wild': 1513,
#   'Montreal Canadiens': 1509,
#   'Nashville Predators': 1554,
#   'New Jersey Devils': 1507,
#   'New York Islanders': 1479,
#   'New York Rangers': 1465,
#   'Ottawa Senators': 1493,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1520,
#   'San Jose Sharks': 1503,
#   'St. Louis Blues': 1458,
#   'Tampa Bay Lightning': 1546,
#   'Toronto Maple Leafs': 1533,
#   'Vancouver Canucks': 1506,
#   'Vegas Golden Knights': 1485,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1527},
#  '2018-10-27': {'Anaheim Ducks': 1484,
#   'Arizona Coyotes': 1507,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1491,
#   'Carolina Hurricanes': 1517,
#   'Chicago Blackhawks': 1504,
#   'Colorado Avalanche': 1517,
#   'Columbus Blue Jackets': 1515,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1431,
#   'Edmonton Oilers': 1514,
#   'Florida Panthers': 1454,
#   'Los Angeles Kings': 1443,
#   'Minnesota Wild': 1523,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1543,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1489,
#   'New York Rangers': 1465,
#   'Ottawa Senators': 1493,
#   'Philadelphia Flyers': 1471,
#   'Pittsburgh Penguins': 1530,
#   'San Jose Sharks': 1503,
#   'St. Louis Blues': 1470,
#   'Tampa Bay Lightning': 1535,
#   'Toronto Maple Leafs': 1543,
#   'Vancouver Canucks': 1496,
#   'Vegas Golden Knights': 1485,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1517},
#  '2018-10-28': {'Anaheim Ducks': 1475,
#   'Arizona Coyotes': 1507,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1491,
#   'Carolina Hurricanes': 1506,
#   'Chicago Blackhawks': 1494,
#   'Colorado Avalanche': 1517,
#   'Columbus Blue Jackets': 1515,
#   'Dallas Stars': 1497,
#   'Detroit Red Wings': 1443,
#   'Edmonton Oilers': 1524,
#   'Florida Panthers': 1454,
#   'Los Angeles Kings': 1454,
#   'Minnesota Wild': 1523,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1543,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1500,
#   'New York Rangers': 1454,
#   'Ottawa Senators': 1483,
#   'Philadelphia Flyers': 1471,
#   'Pittsburgh Penguins': 1530,
#   'San Jose Sharks': 1512,
#   'St. Louis Blues': 1470,
#   'Tampa Bay Lightning': 1535,
#   'Toronto Maple Leafs': 1543,
#   'Vancouver Canucks': 1496,
#   'Vegas Golden Knights': 1495,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1517},
#  '2018-10-29': {'Anaheim Ducks': 1475,
#   'Arizona Coyotes': 1507,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1502,
#   'Carolina Hurricanes': 1506,
#   'Chicago Blackhawks': 1494,
#   'Colorado Avalanche': 1517,
#   'Columbus Blue Jackets': 1515,
#   'Dallas Stars': 1497,
#   'Detroit Red Wings': 1443,
#   'Edmonton Oilers': 1524,
#   'Florida Panthers': 1454,
#   'Los Angeles Kings': 1454,
#   'Minnesota Wild': 1512,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1543,
#   'New Jersey Devils': 1516,
#   'New York Islanders': 1500,
#   'New York Rangers': 1454,
#   'Ottawa Senators': 1483,
#   'Philadelphia Flyers': 1471,
#   'Pittsburgh Penguins': 1530,
#   'San Jose Sharks': 1512,
#   'St. Louis Blues': 1470,
#   'Tampa Bay Lightning': 1535,
#   'Toronto Maple Leafs': 1532,
#   'Vancouver Canucks': 1507,
#   'Vegas Golden Knights': 1495,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1517},
#  '2018-10-30': {'Anaheim Ducks': 1465,
#   'Arizona Coyotes': 1516,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1498,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1496,
#   'Chicago Blackhawks': 1494,
#   'Colorado Avalanche': 1517,
#   'Columbus Blue Jackets': 1503,
#   'Dallas Stars': 1508,
#   'Detroit Red Wings': 1455,
#   'Edmonton Oilers': 1514,
#   'Florida Panthers': 1454,
#   'Los Angeles Kings': 1454,
#   'Minnesota Wild': 1522,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1552,
#   'New Jersey Devils': 1507,
#   'New York Islanders': 1511,
#   'New York Rangers': 1466,
#   'Ottawa Senators': 1474,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1519,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1470,
#   'Tampa Bay Lightning': 1544,
#   'Toronto Maple Leafs': 1532,
#   'Vancouver Canucks': 1507,
#   'Vegas Golden Knights': 1486,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1517},
#  '2018-10-31': {'Anaheim Ducks': 1465,
#   'Arizona Coyotes': 1516,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1498,
#   'Calgary Flames': 1512,
#   'Carolina Hurricanes': 1496,
#   'Chicago Blackhawks': 1484,
#   'Colorado Avalanche': 1517,
#   'Columbus Blue Jackets': 1503,
#   'Dallas Stars': 1508,
#   'Detroit Red Wings': 1455,
#   'Edmonton Oilers': 1514,
#   'Florida Panthers': 1454,
#   'Los Angeles Kings': 1454,
#   'Minnesota Wild': 1522,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1552,
#   'New Jersey Devils': 1507,
#   'New York Islanders': 1511,
#   'New York Rangers': 1466,
#   'Ottawa Senators': 1474,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1519,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1470,
#   'Tampa Bay Lightning': 1544,
#   'Toronto Maple Leafs': 1532,
#   'Vancouver Canucks': 1517,
#   'Vegas Golden Knights': 1486,
#   'Washington Capitals': 1501,
#   'Winnipeg Jets': 1517},
#  '2018-11-01': {'Anaheim Ducks': 1455,
#   'Arizona Coyotes': 1516,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1487,
#   'Calgary Flames': 1522,
#   'Carolina Hurricanes': 1496,
#   'Chicago Blackhawks': 1475,
#   'Colorado Avalanche': 1507,
#   'Columbus Blue Jackets': 1513,
#   'Dallas Stars': 1519,
#   'Detroit Red Wings': 1466,
#   'Edmonton Oilers': 1523,
#   'Florida Panthers': 1446,
#   'Los Angeles Kings': 1445,
#   'Minnesota Wild': 1522,
#   'Montreal Canadiens': 1518,
#   'Nashville Predators': 1562,
#   'New Jersey Devils': 1496,
#   'New York Islanders': 1521,
#   'New York Rangers': 1476,
#   'Ottawa Senators': 1485,
#   'Philadelphia Flyers': 1490,
#   'Pittsburgh Penguins': 1509,
#   'San Jose Sharks': 1490,
#   'St. Louis Blues': 1480,
#   'Tampa Bay Lightning': 1534,
#   'Toronto Maple Leafs': 1521,
#   'Vancouver Canucks': 1517,
#   'Vegas Golden Knights': 1476,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1525},
#  '2018-11-02': {'Anaheim Ducks': 1455,
#   'Arizona Coyotes': 1525,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1487,
#   'Calgary Flames': 1522,
#   'Carolina Hurricanes': 1487,
#   'Chicago Blackhawks': 1475,
#   'Colorado Avalanche': 1497,
#   'Columbus Blue Jackets': 1513,
#   'Dallas Stars': 1519,
#   'Detroit Red Wings': 1466,
#   'Edmonton Oilers': 1523,
#   'Florida Panthers': 1458,
#   'Los Angeles Kings': 1445,
#   'Minnesota Wild': 1522,
#   'Montreal Canadiens': 1518,
#   'Nashville Predators': 1562,
#   'New Jersey Devils': 1496,
#   'New York Islanders': 1521,
#   'New York Rangers': 1476,
#   'Ottawa Senators': 1485,
#   'Philadelphia Flyers': 1490,
#   'Pittsburgh Penguins': 1509,
#   'San Jose Sharks': 1490,
#   'St. Louis Blues': 1480,
#   'Tampa Bay Lightning': 1534,
#   'Toronto Maple Leafs': 1521,
#   'Vancouver Canucks': 1527,
#   'Vegas Golden Knights': 1476,
#   'Washington Capitals': 1491,
#   'Winnipeg Jets': 1513},
#  '2018-11-03': {'Anaheim Ducks': 1455,
#   'Arizona Coyotes': 1525,
#   'Boston Bruins': 1508,
#   'Buffalo Sabres': 1497,
#   'Calgary Flames': 1531,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1466,
#   'Colorado Avalanche': 1497,
#   'Columbus Blue Jackets': 1501,
#   'Dallas Stars': 1528,
#   'Detroit Red Wings': 1458,
#   'Edmonton Oilers': 1531,
#   'Florida Panthers': 1458,
#   'Los Angeles Kings': 1457,
#   'Minnesota Wild': 1531,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1571,
#   'New Jersey Devils': 1487,
#   'New York Islanders': 1530,
#   'New York Rangers': 1476,
#   'Ottawa Senators': 1475,
#   'Philadelphia Flyers': 1480,
#   'Pittsburgh Penguins': 1499,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1471,
#   'Tampa Bay Lightning': 1544,
#   'Toronto Maple Leafs': 1531,
#   'Vancouver Canucks': 1527,
#   'Vegas Golden Knights': 1486,
#   'Washington Capitals': 1482,
#   'Winnipeg Jets': 1513},
#  '2018-11-04': {'Anaheim Ducks': 1466,
#   'Arizona Coyotes': 1525,
#   'Boston Bruins': 1508,
#   'Buffalo Sabres': 1486,
#   'Calgary Flames': 1531,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1466,
#   'Colorado Avalanche': 1497,
#   'Columbus Blue Jackets': 1490,
#   'Dallas Stars': 1528,
#   'Detroit Red Wings': 1458,
#   'Edmonton Oilers': 1531,
#   'Florida Panthers': 1458,
#   'Los Angeles Kings': 1457,
#   'Minnesota Wild': 1531,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1571,
#   'New Jersey Devils': 1487,
#   'New York Islanders': 1530,
#   'New York Rangers': 1487,
#   'Ottawa Senators': 1467,
#   'Philadelphia Flyers': 1480,
#   'Pittsburgh Penguins': 1499,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1471,
#   'Tampa Bay Lightning': 1552,
#   'Toronto Maple Leafs': 1531,
#   'Vancouver Canucks': 1527,
#   'Vegas Golden Knights': 1486,
#   'Washington Capitals': 1482,
#   'Winnipeg Jets': 1513},
#  '2018-11-05': {'Anaheim Ducks': 1466,
#   'Arizona Coyotes': 1514,
#   'Boston Bruins': 1519,
#   'Buffalo Sabres': 1486,
#   'Calgary Flames': 1531,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1466,
#   'Colorado Avalanche': 1497,
#   'Columbus Blue Jackets': 1490,
#   'Dallas Stars': 1517,
#   'Detroit Red Wings': 1458,
#   'Edmonton Oilers': 1520,
#   'Florida Panthers': 1458,
#   'Los Angeles Kings': 1457,
#   'Minnesota Wild': 1531,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1571,
#   'New Jersey Devils': 1497,
#   'New York Islanders': 1519,
#   'New York Rangers': 1487,
#   'Ottawa Senators': 1467,
#   'Philadelphia Flyers': 1491,
#   'Pittsburgh Penguins': 1489,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1471,
#   'Tampa Bay Lightning': 1552,
#   'Toronto Maple Leafs': 1531,
#   'Vancouver Canucks': 1527,
#   'Vegas Golden Knights': 1486,
#   'Washington Capitals': 1493,
#   'Winnipeg Jets': 1513},
#  '2018-11-06': {'Anaheim Ducks': 1456,
#   'Arizona Coyotes': 1514,
#   'Boston Bruins': 1519,
#   'Buffalo Sabres': 1486,
#   'Calgary Flames': 1531,
#   'Carolina Hurricanes': 1467,
#   'Chicago Blackhawks': 1466,
#   'Colorado Avalanche': 1497,
#   'Columbus Blue Jackets': 1501,
#   'Dallas Stars': 1506,
#   'Detroit Red Wings': 1470,
#   'Edmonton Oilers': 1511,
#   'Florida Panthers': 1458,
#   'Los Angeles Kings': 1467,
#   'Minnesota Wild': 1520,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1571,
#   'New Jersey Devils': 1486,
#   'New York Islanders': 1519,
#   'New York Rangers': 1498,
#   'Ottawa Senators': 1478,
#   'Philadelphia Flyers': 1491,
#   'Pittsburgh Penguins': 1489,
#   'San Jose Sharks': 1511,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1561,
#   'Toronto Maple Leafs': 1540,
#   'Vancouver Canucks': 1515,
#   'Vegas Golden Knights': 1477,
#   'Washington Capitals': 1493,
#   'Winnipeg Jets': 1513},
#  '2018-11-07': {'Anaheim Ducks': 1468,
#   'Arizona Coyotes': 1514,
#   'Boston Bruins': 1519,
#   'Buffalo Sabres': 1486,
#   'Calgary Flames': 1519,
#   'Carolina Hurricanes': 1467,
#   'Chicago Blackhawks': 1466,
#   'Colorado Avalanche': 1489,
#   'Columbus Blue Jackets': 1501,
#   'Dallas Stars': 1506,
#   'Detroit Red Wings': 1470,
#   'Edmonton Oilers': 1511,
#   'Florida Panthers': 1458,
#   'Los Angeles Kings': 1467,
#   'Minnesota Wild': 1520,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1579,
#   'New Jersey Devils': 1486,
#   'New York Islanders': 1519,
#   'New York Rangers': 1498,
#   'Ottawa Senators': 1478,
#   'Philadelphia Flyers': 1491,
#   'Pittsburgh Penguins': 1479,
#   'San Jose Sharks': 1511,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1561,
#   'Toronto Maple Leafs': 1540,
#   'Vancouver Canucks': 1515,
#   'Vegas Golden Knights': 1477,
#   'Washington Capitals': 1503,
#   'Winnipeg Jets': 1513},
#  '2018-11-08': {'Anaheim Ducks': 1468,
#   'Arizona Coyotes': 1503,
#   'Boston Bruins': 1509,
#   'Buffalo Sabres': 1497,
#   'Calgary Flames': 1519,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1456,
#   'Colorado Avalanche': 1489,
#   'Columbus Blue Jackets': 1501,
#   'Dallas Stars': 1516,
#   'Detroit Red Wings': 1470,
#   'Edmonton Oilers': 1499,
#   'Florida Panthers': 1470,
#   'Los Angeles Kings': 1459,
#   'Minnesota Wild': 1528,
#   'Montreal Canadiens': 1497,
#   'Nashville Predators': 1579,
#   'New Jersey Devils': 1486,
#   'New York Islanders': 1510,
#   'New York Rangers': 1498,
#   'Ottawa Senators': 1468,
#   'Philadelphia Flyers': 1502,
#   'Pittsburgh Penguins': 1479,
#   'San Jose Sharks': 1501,
#   'St. Louis Blues': 1481,
#   'Tampa Bay Lightning': 1570,
#   'Toronto Maple Leafs': 1540,
#   'Vancouver Canucks': 1525,
#   'Vegas Golden Knights': 1487,
#   'Washington Capitals': 1503,
#   'Winnipeg Jets': 1513},
#  '2018-11-09': {'Anaheim Ducks': 1460,
#   'Arizona Coyotes': 1503,
#   'Boston Bruins': 1509,
#   'Buffalo Sabres': 1497,
#   'Calgary Flames': 1519,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1456,
#   'Colorado Avalanche': 1480,
#   'Columbus Blue Jackets': 1511,
#   'Dallas Stars': 1516,
#   'Detroit Red Wings': 1481,
#   'Edmonton Oilers': 1499,
#   'Florida Panthers': 1470,
#   'Los Angeles Kings': 1459,
#   'Minnesota Wild': 1536,
#   'Montreal Canadiens': 1497,
#   'Nashville Predators': 1579,
#   'New Jersey Devils': 1478,
#   'New York Islanders': 1510,
#   'New York Rangers': 1487,
#   'Ottawa Senators': 1468,
#   'Philadelphia Flyers': 1502,
#   'Pittsburgh Penguins': 1479,
#   'San Jose Sharks': 1490,
#   'St. Louis Blues': 1492,
#   'Tampa Bay Lightning': 1570,
#   'Toronto Maple Leafs': 1548,
#   'Vancouver Canucks': 1525,
#   'Vegas Golden Knights': 1487,
#   'Washington Capitals': 1493,
#   'Winnipeg Jets': 1522},
#  '2018-11-10': {'Anaheim Ducks': 1460,
#   'Arizona Coyotes': 1492,
#   'Boston Bruins': 1520,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1527,
#   'Carolina Hurricanes': 1467,
#   'Chicago Blackhawks': 1447,
#   'Colorado Avalanche': 1480,
#   'Columbus Blue Jackets': 1500,
#   'Dallas Stars': 1508,
#   'Detroit Red Wings': 1491,
#   'Edmonton Oilers': 1499,
#   'Florida Panthers': 1481,
#   'Los Angeles Kings': 1451,
#   'Minnesota Wild': 1536,
#   'Montreal Canadiens': 1507,
#   'Nashville Predators': 1587,
#   'New Jersey Devils': 1478,
#   'New York Islanders': 1499,
#   'New York Rangers': 1498,
#   'Ottawa Senators': 1481,
#   'Philadelphia Flyers': 1511,
#   'Pittsburgh Penguins': 1490,
#   'San Jose Sharks': 1490,
#   'St. Louis Blues': 1492,
#   'Tampa Bay Lightning': 1557,
#   'Toronto Maple Leafs': 1537,
#   'Vancouver Canucks': 1514,
#   'Vegas Golden Knights': 1477,
#   'Washington Capitals': 1493,
#   'Winnipeg Jets': 1522},
#  '2018-11-11': {'Anaheim Ducks': 1460,
#   'Arizona Coyotes': 1502,
#   'Boston Bruins': 1529,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1516,
#   'Carolina Hurricanes': 1467,
#   'Chicago Blackhawks': 1447,
#   'Colorado Avalanche': 1491,
#   'Columbus Blue Jackets': 1500,
#   'Dallas Stars': 1508,
#   'Detroit Red Wings': 1491,
#   'Edmonton Oilers': 1488,
#   'Florida Panthers': 1491,
#   'Los Angeles Kings': 1451,
#   'Minnesota Wild': 1545,
#   'Montreal Canadiens': 1507,
#   'Nashville Predators': 1587,
#   'New Jersey Devils': 1469,
#   'New York Islanders': 1499,
#   'New York Rangers': 1498,
#   'Ottawa Senators': 1471,
#   'Philadelphia Flyers': 1511,
#   'Pittsburgh Penguins': 1490,
#   'San Jose Sharks': 1501,
#   'St. Louis Blues': 1483,
#   'Tampa Bay Lightning': 1557,
#   'Toronto Maple Leafs': 1537,
#   'Vancouver Canucks': 1514,
#   'Vegas Golden Knights': 1468,
#   'Washington Capitals': 1483,
#   'Winnipeg Jets': 1531},
#  '2018-11-12': {'Anaheim Ducks': 1474,
#   'Arizona Coyotes': 1502,
#   'Boston Bruins': 1529,
#   'Buffalo Sabres': 1508,
#   'Calgary Flames': 1516,
#   'Carolina Hurricanes': 1476,
#   'Chicago Blackhawks': 1438,
#   'Colorado Avalanche': 1491,
#   'Columbus Blue Jackets': 1510,
#   'Dallas Stars': 1498,
#   'Detroit Red Wings': 1491,
#   'Edmonton Oilers': 1488,
#   'Florida Panthers': 1491,
#   'Los Angeles Kings': 1451,
#   'Minnesota Wild': 1545,
#   'Montreal Canadiens': 1507,
#   'Nashville Predators': 1573,
#   'New Jersey Devils': 1469,
#   'New York Islanders': 1499,
#   'New York Rangers': 1508,
#   'Ottawa Senators': 1471,
#   'Philadelphia Flyers': 1511,
#   'Pittsburgh Penguins': 1490,
#   'San Jose Sharks': 1501,
#   'St. Louis Blues': 1483,
#   'Tampa Bay Lightning': 1557,
#   'Toronto Maple Leafs': 1537,
#   'Vancouver Canucks': 1504,
#   'Vegas Golden Knights': 1468,
#   'Washington Capitals': 1483,
#   'Winnipeg Jets': 1531},
#  '2018-11-13': {'Anaheim Ducks': 1474,
#   'Arizona Coyotes': 1492,
#   'Boston Bruins': 1529,
#   'Buffalo Sabres': 1519,
#   'Calgary Flames': 1516,
#   'Carolina Hurricanes': 1476,
#   'Chicago Blackhawks': 1438,
#   'Colorado Avalanche': 1491,
#   'Columbus Blue Jackets': 1510,
#   'Dallas Stars': 1498,
#   'Detroit Red Wings': 1501,
#   'Edmonton Oilers': 1499,
#   'Florida Panthers': 1502,
#   'Los Angeles Kings': 1443,
#   'Minnesota Wild': 1533,
#   'Montreal Canadiens': 1496,
#   'Nashville Predators': 1561,
#   'New Jersey Devils': 1480,
#   'New York Islanders': 1509,
#   'New York Rangers': 1508,
#   'Ottawa Senators': 1471,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1479,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1483,
#   'Tampa Bay Lightning': 1546,
#   'Toronto Maple Leafs': 1545,
#   'Vancouver Canucks': 1494,
#   'Vegas Golden Knights': 1468,
#   'Washington Capitals': 1495,
#   'Winnipeg Jets': 1531},
#  '2018-11-14': {'Anaheim Ducks': 1464,
#   'Arizona Coyotes': 1492,
#   'Boston Bruins': 1518,
#   'Buffalo Sabres': 1519,
#   'Calgary Flames': 1516,
#   'Carolina Hurricanes': 1476,
#   'Chicago Blackhawks': 1449,
#   'Colorado Avalanche': 1502,
#   'Columbus Blue Jackets': 1510,
#   'Dallas Stars': 1498,
#   'Detroit Red Wings': 1501,
#   'Edmonton Oilers': 1499,
#   'Florida Panthers': 1502,
#   'Los Angeles Kings': 1443,
#   'Minnesota Wild': 1533,
#   'Montreal Canadiens': 1496,
#   'Nashville Predators': 1561,
#   'New Jersey Devils': 1480,
#   'New York Islanders': 1509,
#   'New York Rangers': 1508,
#   'Ottawa Senators': 1471,
#   'Philadelphia Flyers': 1500,
#   'Pittsburgh Penguins': 1479,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1472,
#   'Tampa Bay Lightning': 1546,
#   'Toronto Maple Leafs': 1545,
#   'Vancouver Canucks': 1494,
#   'Vegas Golden Knights': 1478,
#   'Washington Capitals': 1486,
#   'Winnipeg Jets': 1540},
#  '2018-11-15': {'Anaheim Ducks': 1464,
#   'Arizona Coyotes': 1504,
#   'Boston Bruins': 1518,
#   'Buffalo Sabres': 1519,
#   'Calgary Flames': 1505,
#   'Carolina Hurricanes': 1476,
#   'Chicago Blackhawks': 1449,
#   'Colorado Avalanche': 1502,
#   'Columbus Blue Jackets': 1520,
#   'Dallas Stars': 1498,
#   'Detroit Red Wings': 1490,
#   'Edmonton Oilers': 1499,
#   'Florida Panthers': 1492,
#   'Los Angeles Kings': 1443,
#   'Minnesota Wild': 1542,
#   'Montreal Canadiens': 1507,
#   'Nashville Predators': 1549,
#   'New Jersey Devils': 1491,
#   'New York Islanders': 1519,
#   'New York Rangers': 1498,
#   'Ottawa Senators': 1482,
#   'Philadelphia Flyers': 1489,
#   'Pittsburgh Penguins': 1471,
#   'San Jose Sharks': 1504,
#   'St. Louis Blues': 1472,
#   'Tampa Bay Lightning': 1554,
#   'Toronto Maple Leafs': 1554,
#   'Vancouver Canucks': 1485,
#   'Vegas Golden Knights': 1478,
#   'Washington Capitals': 1486,
#   'Winnipeg Jets': 1540},
#  '2018-11-16': {'Anaheim Ducks': 1457,
#   'Arizona Coyotes': 1504,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1530,
#   'Calgary Flames': 1505,
#   'Carolina Hurricanes': 1476,
#   'Chicago Blackhawks': 1439,
#   'Colorado Avalanche': 1492,
#   'Columbus Blue Jackets': 1520,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1490,
#   'Edmonton Oilers': 1499,
#   'Florida Panthers': 1492,
#   'Los Angeles Kings': 1453,
#   'Minnesota Wild': 1542,
#   'Montreal Canadiens': 1507,
#   'Nashville Predators': 1549,
#   'New Jersey Devils': 1491,
#   'New York Islanders': 1519,
#   'New York Rangers': 1498,
#   'Ottawa Senators': 1482,
#   'Philadelphia Flyers': 1489,
#   'Pittsburgh Penguins': 1471,
#   'San Jose Sharks': 1504,
#   'St. Louis Blues': 1482,
#   'Tampa Bay Lightning': 1554,
#   'Toronto Maple Leafs': 1561,
#   'Vancouver Canucks': 1485,
#   'Vegas Golden Knights': 1468,
#   'Washington Capitals': 1496,
#   'Winnipeg Jets': 1529},
#  '2018-11-17': {'Anaheim Ducks': 1457,
#   'Arizona Coyotes': 1494,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1540,
#   'Calgary Flames': 1515,
#   'Carolina Hurricanes': 1467,
#   'Chicago Blackhawks': 1439,
#   'Colorado Avalanche': 1492,
#   'Columbus Blue Jackets': 1529,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1500,
#   'Edmonton Oilers': 1489,
#   'Florida Panthers': 1482,
#   'Los Angeles Kings': 1446,
#   'Minnesota Wild': 1532,
#   'Montreal Canadiens': 1516,
#   'Nashville Predators': 1556,
#   'New Jersey Devils': 1481,
#   'New York Islanders': 1519,
#   'New York Rangers': 1508,
#   'Ottawa Senators': 1492,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1461,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1473,
#   'Tampa Bay Lightning': 1562,
#   'Toronto Maple Leafs': 1561,
#   'Vancouver Canucks': 1476,
#   'Vegas Golden Knights': 1468,
#   'Washington Capitals': 1496,
#   'Winnipeg Jets': 1529},
#  '2018-11-18': {'Anaheim Ducks': 1448,
#   'Arizona Coyotes': 1494,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1540,
#   'Calgary Flames': 1515,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1452,
#   'Colorado Avalanche': 1501,
#   'Columbus Blue Jackets': 1529,
#   'Dallas Stars': 1519,
#   'Detroit Red Wings': 1500,
#   'Edmonton Oilers': 1478,
#   'Florida Panthers': 1482,
#   'Los Angeles Kings': 1446,
#   'Minnesota Wild': 1519,
#   'Montreal Canadiens': 1516,
#   'Nashville Predators': 1556,
#   'New Jersey Devils': 1471,
#   'New York Islanders': 1509,
#   'New York Rangers': 1508,
#   'Ottawa Senators': 1492,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1461,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1473,
#   'Tampa Bay Lightning': 1562,
#   'Toronto Maple Leafs': 1561,
#   'Vancouver Canucks': 1476,
#   'Vegas Golden Knights': 1479,
#   'Washington Capitals': 1496,
#   'Winnipeg Jets': 1529},
#  '2018-11-19': {'Anaheim Ducks': 1448,
#   'Arizona Coyotes': 1494,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1548,
#   'Calgary Flames': 1524,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1452,
#   'Colorado Avalanche': 1501,
#   'Columbus Blue Jackets': 1520,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1500,
#   'Edmonton Oilers': 1478,
#   'Florida Panthers': 1492,
#   'Los Angeles Kings': 1457,
#   'Minnesota Wild': 1519,
#   'Montreal Canadiens': 1505,
#   'Nashville Predators': 1566,
#   'New Jersey Devils': 1471,
#   'New York Islanders': 1509,
#   'New York Rangers': 1518,
#   'Ottawa Senators': 1482,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1453,
#   'San Jose Sharks': 1513,
#   'St. Louis Blues': 1462,
#   'Tampa Bay Lightning': 1552,
#   'Toronto Maple Leafs': 1570,
#   'Vancouver Canucks': 1468,
#   'Vegas Golden Knights': 1470,
#   'Washington Capitals': 1507,
#   'Winnipeg Jets': 1537},
#  '2018-11-20': {'Anaheim Ducks': 1448,
#   'Arizona Coyotes': 1494,
#   'Boston Bruins': 1517,
#   'Buffalo Sabres': 1548,
#   'Calgary Flames': 1524,
#   'Carolina Hurricanes': 1477,
#   'Chicago Blackhawks': 1452,
#   'Colorado Avalanche': 1501,
#   'Columbus Blue Jackets': 1520,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1500,
#   'Edmonton Oilers': 1489,
#   'Florida Panthers': 1492,
#   'Los Angeles Kings': 1457,
#   'Minnesota Wild': 1519,
#   'Montreal Canadiens': 1505,
#   'Nashville Predators': 1566,
#   'New Jersey Devils': 1471,
#   'New York Islanders': 1509,
#   'New York Rangers': 1518,
#   'Ottawa Senators': 1482,
#   'Philadelphia Flyers': 1481,
#   'Pittsburgh Penguins': 1453,
#   'San Jose Sharks': 1502,
#   'St. Louis Blues': 1462,
#   'Tampa Bay Lightning': 1552,
#   'Toronto Maple Leafs': 1570,
#   'Vancouver Canucks': 1468,
#   'Vegas Golden Knights': 1470,
#   'Washington Capitals': 1507,
#   'Winnipeg Jets': 1537},
#  '2018-11-21': {'Anaheim Ducks': 1459,
#   'Arizona Coyotes': 1483,
#   'Boston Bruins': 1507,
#   'Buffalo Sabres': 1556,
#   'Calgary Flames': 1534,
#   'Carolina Hurricanes': 1490,
#   'Chicago Blackhawks': 1444,
#   'Colorado Avalanche': 1510,
#   'Columbus Blue Jackets': 1520,
#   'Dallas Stars': 1497,
#   'Detroit Red Wings': 1510,
#   'Edmonton Oilers': 1489,
#   'Florida Panthers': 1484,
#   'Los Angeles Kings': 1448,
#   'Minnesota Wild': 1528,
#   'Montreal Canadiens': 1494,
#   'Nashville Predators': 1573,
#   'New Jersey Devils': 1482,
#   'New York Islanders': 1499,
#   'New York Rangers': 1528,
#   'Ottawa Senators': 1473,
#   'Philadelphia Flyers': 1473,
#   'Pittsburgh Penguins': 1465,
#   'San Jose Sharks': 1502,
#   'St. Louis Blues': 1455,
#   'Tampa Bay Lightning': 1560,
#   'Toronto Maple Leafs': 1557,
#   'Vancouver Canucks': 1457,
#   'Vegas Golden Knights': 1481,
#   'Washington Capitals': 1515,
#   'Winnipeg Jets': 1527},
#  '2018-11-23': {'Anaheim Ducks': 1470,
#   'Arizona Coyotes': 1474,
#   'Boston Bruins': 1516,
#   'Buffalo Sabres': 1564,
#   'Calgary Flames': 1522,
#   'Carolina Hurricanes': 1500,
#   'Chicago Blackhawks': 1437,
#   'Colorado Avalanche': 1519,
#   'Columbus Blue Jackets': 1531,
#   'Dallas Stars': 1506,
#   'Detroit Red Wings': 1500,
#   'Edmonton Oilers': 1478,
#   'Florida Panthers': 1474,
#   'Los Angeles Kings': 1448,
#   'Minnesota Wild': 1538,
#   'Montreal Canadiens': 1486,
#   'Nashville Predators': 1560,
#   'New Jersey Devils': 1472,
#   'New York Islanders': 1509,
#   'New York Rangers': 1516,
#   'Ottawa Senators': 1464,
#   'Philadelphia Flyers': 1485,
#   'Pittsburgh Penguins': 1456,
#   'San Jose Sharks': 1511,
#   'St. Louis Blues': 1468,
#   'Tampa Bay Lightning': 1567,
#   'Toronto Maple Leafs': 1546,
#   'Vancouver Canucks': 1448,
#   'Vegas Golden Knights': 1493,
#   'Washington Capitals': 1525,
#   'Winnipeg Jets': 1517},
#  '2018-11-24': {'Anaheim Ducks': 1470,
#   'Arizona Coyotes': 1474,
#   'Boston Bruins': 1525,
#   'Buffalo Sabres': 1572,
#   'Calgary Flames': 1522,
#   'Carolina Hurricanes': 1490,
#   'Chicago Blackhawks': 1448,
#   'Colorado Avalanche': 1529,
#   'Columbus Blue Jackets': 1519,
#   'Dallas Stars': 1496,
#   'Detroit Red Wings': 1492,
#   'Edmonton Oilers': 1478,
#   'Florida Panthers': 1463,
#   'Los Angeles Kings': 1438,
#   'Minnesota Wild': 1538,
#   'Montreal Canadiens': 1477,
#   'Nashville Predators': 1560,
#   'New Jersey Devils': 1472,
#   'New York Islanders': 1519,
#   'New York Rangers': 1506,
#   'Ottawa Senators': 1464,
#   'Philadelphia Flyers': 1477,
#   'Pittsburgh Penguins': 1468,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1459,
#   'Tampa Bay Lightning': 1567,
#   'Toronto Maple Leafs': 1554,
#   'Vancouver Canucks': 1458,
#   'Vegas Golden Knights': 1504,
#   'Washington Capitals': 1535,
#   'Winnipeg Jets': 1526},
#  '2018-11-25': {'Anaheim Ducks': 1463,
#   'Arizona Coyotes': 1465,
#   'Boston Bruins': 1525,
#   'Buffalo Sabres': 1572,
#   'Calgary Flames': 1531,
#   'Carolina Hurricanes': 1490,
#   'Chicago Blackhawks': 1448,
#   'Colorado Avalanche': 1529,
#   'Columbus Blue Jackets': 1519,
#   'Dallas Stars': 1496,
#   'Detroit Red Wings': 1492,
#   'Edmonton Oilers': 1467,
#   'Florida Panthers': 1463,
#   'Los Angeles Kings': 1449,
#   'Minnesota Wild': 1538,
#   'Montreal Canadiens': 1477,
#   'Nashville Predators': 1567,
#   'New Jersey Devils': 1465,
#   'New York Islanders': 1519,
#   'New York Rangers': 1506,
#   'Ottawa Senators': 1464,
#   'Philadelphia Flyers': 1477,
#   'Pittsburgh Penguins': 1468,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1459,
#   'Tampa Bay Lightning': 1574,
#   'Toronto Maple Leafs': 1554,
#   'Vancouver Canucks': 1458,
#   'Vegas Golden Knights': 1504,
#   'Washington Capitals': 1535,
#   'Winnipeg Jets': 1526},
#  '2018-11-26': {'Anaheim Ducks': 1463,
#   'Arizona Coyotes': 1465,
#   'Boston Bruins': 1516,
#   'Buffalo Sabres': 1572,
#   'Calgary Flames': 1531,
#   'Carolina Hurricanes': 1490,
#   'Chicago Blackhawks': 1448,
#   'Colorado Avalanche': 1529,
#   'Columbus Blue Jackets': 1528,
#   'Dallas Stars': 1496,
#   'Detroit Red Wings': 1483,
#   'Edmonton Oilers': 1467,
#   'Florida Panthers': 1473,
#   'Los Angeles Kings': 1449,
#   'Minnesota Wild': 1538,
#   'Montreal Canadiens': 1477,
#   'Nashville Predators': 1567,
#   'New Jersey Devils': 1455,
#   'New York Islanders': 1509,
#   'New York Rangers': 1515,
#   'Ottawa Senators': 1455,
#   'Philadelphia Flyers': 1477,
#   'Pittsburgh Penguins': 1468,
#   'San Jose Sharks': 1500,
#   'St. Louis Blues': 1459,
#   'Tampa Bay Lightning': 1574,
#   'Toronto Maple Leafs': 1563,
#   'Vancouver Canucks': 1458,
#   'Vegas Golden Knights': 1504,
#   'Washington Capitals': 1545,
#   'Winnipeg Jets': 1526},
#  '2018-11-27': {'Anaheim Ducks': 1476,
#   'Arizona Coyotes': 1477,
#   'Boston Bruins': 1516,
#   'Buffalo Sabres': 1580,
#   'Calgary Flames': 1531,
#   'Carolina Hurricanes': 1500,
#   'Chicago Blackhawks': 1440,
#   'Colorado Avalanche': 1540,
# ...
#   'Columbus Blue Jackets': 1533,
#   'Dallas Stars': 1522,
#   'Detroit Red Wings': 1390,
#   'Edmonton Oilers': 1462,
#   'Florida Panthers': 1494,
#   'Los Angeles Kings': 1393,
#   'Minnesota Wild': 1468,
#   'Montreal Canadiens': 1488,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1419,
#   'New York Islanders': 1544,
#   'New York Rangers': 1402,
#   'Ottawa Senators': 1399,
#   'Philadelphia Flyers': 1515,
#   'Pittsburgh Penguins': 1544,
#   'San Jose Sharks': 1588,
#   'St. Louis Blues': 1543,
#   'Tampa Bay Lightning': 1685,
#   'Toronto Maple Leafs': 1532,
#   'Vancouver Canucks': 1416,
#   'Vegas Golden Knights': 1539,
#   'Washington Capitals': 1563,
#   'Winnipeg Jets': 1539},
#  '2019-03-17': {'Anaheim Ducks': 1437,
#   'Arizona Coyotes': 1526,
#   'Boston Bruins': 1587,
#   'Buffalo Sabres': 1418,
#   'Calgary Flames': 1560,
#   'Carolina Hurricanes': 1563,
#   'Chicago Blackhawks': 1514,
#   'Colorado Avalanche': 1437,
#   'Columbus Blue Jackets': 1533,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1390,
#   'Edmonton Oilers': 1454,
#   'Florida Panthers': 1482,
#   'Los Angeles Kings': 1393,
#   'Minnesota Wild': 1460,
#   'Montreal Canadiens': 1488,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1409,
#   'New York Islanders': 1552,
#   'New York Rangers': 1402,
#   'Ottawa Senators': 1399,
#   'Philadelphia Flyers': 1526,
#   'Pittsburgh Penguins': 1533,
#   'San Jose Sharks': 1588,
#   'St. Louis Blues': 1529,
#   'Tampa Bay Lightning': 1685,
#   'Toronto Maple Leafs': 1532,
#   'Vancouver Canucks': 1429,
#   'Vegas Golden Knights': 1547,
#   'Washington Capitals': 1563,
#   'Winnipeg Jets': 1539},
#  '2019-03-18': {'Anaheim Ducks': 1437,
#   'Arizona Coyotes': 1520,
#   'Boston Bruins': 1587,
#   'Buffalo Sabres': 1418,
#   'Calgary Flames': 1560,
#   'Carolina Hurricanes': 1563,
#   'Chicago Blackhawks': 1502,
#   'Colorado Avalanche': 1437,
#   'Columbus Blue Jackets': 1533,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1390,
#   'Edmonton Oilers': 1454,
#   'Florida Panthers': 1482,
#   'Los Angeles Kings': 1387,
#   'Minnesota Wild': 1460,
#   'Montreal Canadiens': 1488,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1409,
#   'New York Islanders': 1552,
#   'New York Rangers': 1402,
#   'Ottawa Senators': 1399,
#   'Philadelphia Flyers': 1526,
#   'Pittsburgh Penguins': 1533,
#   'San Jose Sharks': 1577,
#   'St. Louis Blues': 1529,
#   'Tampa Bay Lightning': 1691,
#   'Toronto Maple Leafs': 1532,
#   'Vancouver Canucks': 1441,
#   'Vegas Golden Knights': 1558,
#   'Washington Capitals': 1563,
#   'Winnipeg Jets': 1545},
#  '2019-03-19': {'Anaheim Ducks': 1437,
#   'Arizona Coyotes': 1520,
#   'Boston Bruins': 1596,
#   'Buffalo Sabres': 1418,
#   'Calgary Flames': 1569,
#   'Carolina Hurricanes': 1572,
#   'Chicago Blackhawks': 1502,
#   'Colorado Avalanche': 1448,
#   'Columbus Blue Jackets': 1524,
#   'Dallas Stars': 1518,
#   'Detroit Red Wings': 1400,
#   'Edmonton Oilers': 1446,
#   'Florida Panthers': 1473,
#   'Los Angeles Kings': 1387,
#   'Minnesota Wild': 1449,
#   'Montreal Canadiens': 1499,
#   'Nashville Predators': 1526,
#   'New Jersey Devils': 1403,
#   'New York Islanders': 1543,
#   'New York Rangers': 1392,
#   'Ottawa Senators': 1399,
#   'Philadelphia Flyers': 1515,
#   'Pittsburgh Penguins': 1524,
#   'San Jose Sharks': 1577,
#   'St. Louis Blues': 1537,
#   'Tampa Bay Lightning': 1691,
#   'Toronto Maple Leafs': 1522,
#   'Vancouver Canucks': 1441,
#   'Vegas Golden Knights': 1558,
#   'Washington Capitals': 1569,
#   'Winnipeg Jets': 1545},
#  '2019-03-20': {'Anaheim Ducks': 1430,
#   'Arizona Coyotes': 1520,
#   'Boston Bruins': 1596,
#   'Buffalo Sabres': 1411,
#   'Calgary Flames': 1569,
#   'Carolina Hurricanes': 1572,
#   'Chicago Blackhawks': 1502,
#   'Colorado Avalanche': 1448,
#   'Columbus Blue Jackets': 1524,
#   'Dallas Stars': 1518,
#   'Detroit Red Wings': 1400,
#   'Edmonton Oilers': 1446,
#   'Florida Panthers': 1473,
#   'Los Angeles Kings': 1387,
#   'Minnesota Wild': 1449,
#   'Montreal Canadiens': 1499,
#   'Nashville Predators': 1526,
#   'New Jersey Devils': 1403,
#   'New York Islanders': 1543,
#   'New York Rangers': 1392,
#   'Ottawa Senators': 1390,
#   'Philadelphia Flyers': 1515,
#   'Pittsburgh Penguins': 1524,
#   'San Jose Sharks': 1577,
#   'St. Louis Blues': 1537,
#   'Tampa Bay Lightning': 1698,
#   'Toronto Maple Leafs': 1529,
#   'Vancouver Canucks': 1450,
#   'Vegas Golden Knights': 1558,
#   'Washington Capitals': 1562,
#   'Winnipeg Jets': 1552},
#  '2019-03-21': {'Anaheim Ducks': 1430,
#   'Arizona Coyotes': 1509,
#   'Boston Bruins': 1601,
#   'Buffalo Sabres': 1411,
#   'Calgary Flames': 1574,
#   'Carolina Hurricanes': 1565,
#   'Chicago Blackhawks': 1492,
#   'Colorado Avalanche': 1460,
#   'Columbus Blue Jackets': 1512,
#   'Dallas Stars': 1506,
#   'Detroit Red Wings': 1394,
#   'Edmonton Oilers': 1458,
#   'Florida Panthers': 1484,
#   'Los Angeles Kings': 1402,
#   'Minnesota Wild': 1449,
#   'Montreal Canadiens': 1510,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1398,
#   'New York Islanders': 1532,
#   'New York Rangers': 1392,
#   'Ottawa Senators': 1385,
#   'Philadelphia Flyers': 1525,
#   'Pittsburgh Penguins': 1534,
#   'San Jose Sharks': 1562,
#   'St. Louis Blues': 1543,
#   'Tampa Bay Lightning': 1705,
#   'Toronto Maple Leafs': 1529,
#   'Vancouver Canucks': 1450,
#   'Vegas Golden Knights': 1568,
#   'Washington Capitals': 1562,
#   'Winnipeg Jets': 1542},
#  '2019-03-22': {'Anaheim Ducks': 1444,
#   'Arizona Coyotes': 1509,
#   'Boston Bruins': 1601,
#   'Buffalo Sabres': 1411,
#   'Calgary Flames': 1574,
#   'Carolina Hurricanes': 1565,
#   'Chicago Blackhawks': 1492,
#   'Colorado Avalanche': 1460,
#   'Columbus Blue Jackets': 1512,
#   'Dallas Stars': 1506,
#   'Detroit Red Wings': 1394,
#   'Edmonton Oilers': 1458,
#   'Florida Panthers': 1484,
#   'Los Angeles Kings': 1402,
#   'Minnesota Wild': 1462,
#   'Montreal Canadiens': 1510,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1398,
#   'New York Islanders': 1532,
#   'New York Rangers': 1392,
#   'Ottawa Senators': 1385,
#   'Philadelphia Flyers': 1525,
#   'Pittsburgh Penguins': 1534,
#   'San Jose Sharks': 1548,
#   'St. Louis Blues': 1543,
#   'Tampa Bay Lightning': 1705,
#   'Toronto Maple Leafs': 1529,
#   'Vancouver Canucks': 1450,
#   'Vegas Golden Knights': 1568,
#   'Washington Capitals': 1549,
#   'Winnipeg Jets': 1542},
#  '2019-03-23': {'Anaheim Ducks': 1433,
#   'Arizona Coyotes': 1496,
#   'Boston Bruins': 1608,
#   'Buffalo Sabres': 1404,
#   'Calgary Flames': 1581,
#   'Carolina Hurricanes': 1572,
#   'Chicago Blackhawks': 1481,
#   'Colorado Avalanche': 1471,
#   'Columbus Blue Jackets': 1512,
#   'Dallas Stars': 1497,
#   'Detroit Red Wings': 1409,
#   'Edmonton Oilers': 1446,
#   'Florida Panthers': 1477,
#   'Los Angeles Kings': 1413,
#   'Minnesota Wild': 1455,
#   'Montreal Canadiens': 1517,
#   'Nashville Predators': 1507,
#   'New Jersey Devils': 1411,
#   'New York Islanders': 1542,
#   'New York Rangers': 1406,
#   'Ottawa Senators': 1397,
#   'Philadelphia Flyers': 1515,
#   'Pittsburgh Penguins': 1543,
#   'San Jose Sharks': 1548,
#   'St. Louis Blues': 1557,
#   'Tampa Bay Lightning': 1691,
#   'Toronto Maple Leafs': 1515,
#   'Vancouver Canucks': 1443,
#   'Vegas Golden Knights': 1553,
#   'Washington Capitals': 1549,
#   'Winnipeg Jets': 1551},
#  '2019-03-24': {'Anaheim Ducks': 1433,
#   'Arizona Coyotes': 1487,
#   'Boston Bruins': 1608,
#   'Buffalo Sabres': 1404,
#   'Calgary Flames': 1581,
#   'Carolina Hurricanes': 1580,
#   'Chicago Blackhawks': 1491,
#   'Colorado Avalanche': 1461,
#   'Columbus Blue Jackets': 1520,
#   'Dallas Stars': 1497,
#   'Detroit Red Wings': 1409,
#   'Edmonton Oilers': 1446,
#   'Florida Panthers': 1477,
#   'Los Angeles Kings': 1413,
#   'Minnesota Wild': 1455,
#   'Montreal Canadiens': 1509,
#   'Nashville Predators': 1507,
#   'New Jersey Devils': 1411,
#   'New York Islanders': 1551,
#   'New York Rangers': 1406,
#   'Ottawa Senators': 1397,
#   'Philadelphia Flyers': 1506,
#   'Pittsburgh Penguins': 1543,
#   'San Jose Sharks': 1548,
#   'St. Louis Blues': 1557,
#   'Tampa Bay Lightning': 1691,
#   'Toronto Maple Leafs': 1515,
#   'Vancouver Canucks': 1435,
#   'Vegas Golden Knights': 1553,
#   'Washington Capitals': 1558,
#   'Winnipeg Jets': 1551},
#  '2019-03-25': {'Anaheim Ducks': 1433,
#   'Arizona Coyotes': 1487,
#   'Boston Bruins': 1600,
#   'Buffalo Sabres': 1394,
#   'Calgary Flames': 1567,
#   'Carolina Hurricanes': 1580,
#   'Chicago Blackhawks': 1491,
#   'Colorado Avalanche': 1461,
#   'Columbus Blue Jackets': 1520,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1423,
#   'Edmonton Oilers': 1446,
#   'Florida Panthers': 1468,
#   'Los Angeles Kings': 1427,
#   'Minnesota Wild': 1446,
#   'Montreal Canadiens': 1509,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1421,
#   'New York Islanders': 1551,
#   'New York Rangers': 1400,
#   'Ottawa Senators': 1397,
#   'Philadelphia Flyers': 1506,
#   'Pittsburgh Penguins': 1549,
#   'San Jose Sharks': 1534,
#   'St. Louis Blues': 1567,
#   'Tampa Bay Lightning': 1699,
#   'Toronto Maple Leafs': 1524,
#   'Vancouver Canucks': 1435,
#   'Vegas Golden Knights': 1543,
#   'Washington Capitals': 1558,
#   'Winnipeg Jets': 1539},
#  '2019-03-26': {'Anaheim Ducks': 1443,
#   'Arizona Coyotes': 1497,
#   'Boston Bruins': 1600,
#   'Buffalo Sabres': 1384,
#   'Calgary Flames': 1567,
#   'Carolina Hurricanes': 1569,
#   'Chicago Blackhawks': 1481,
#   'Colorado Avalanche': 1461,
#   'Columbus Blue Jackets': 1531,
#   'Dallas Stars': 1509,
#   'Detroit Red Wings': 1423,
#   'Edmonton Oilers': 1455,
#   'Florida Panthers': 1459,
#   'Los Angeles Kings': 1418,
#   'Minnesota Wild': 1446,
#   'Montreal Canadiens': 1518,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1421,
#   'New York Islanders': 1540,
#   'New York Rangers': 1400,
#   'Ottawa Senators': 1407,
#   'Philadelphia Flyers': 1506,
#   'Pittsburgh Penguins': 1549,
#   'San Jose Sharks': 1534,
#   'St. Louis Blues': 1567,
#   'Tampa Bay Lightning': 1699,
#   'Toronto Maple Leafs': 1524,
#   'Vancouver Canucks': 1425,
#   'Vegas Golden Knights': 1543,
#   'Washington Capitals': 1569,
#   'Winnipeg Jets': 1539},
#  '2019-03-27': {'Anaheim Ducks': 1443,
#   'Arizona Coyotes': 1497,
#   'Boston Bruins': 1605,
#   'Buffalo Sabres': 1384,
#   'Calgary Flames': 1555,
#   'Carolina Hurricanes': 1569,
#   'Chicago Blackhawks': 1481,
#   'Colorado Avalanche': 1473,
#   'Columbus Blue Jackets': 1531,
#   'Dallas Stars': 1521,
#   'Detroit Red Wings': 1423,
#   'Edmonton Oilers': 1455,
#   'Florida Panthers': 1459,
#   'Los Angeles Kings': 1418,
#   'Minnesota Wild': 1446,
#   'Montreal Canadiens': 1518,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1421,
#   'New York Islanders': 1540,
#   'New York Rangers': 1395,
#   'Ottawa Senators': 1407,
#   'Philadelphia Flyers': 1517,
#   'Pittsburgh Penguins': 1549,
#   'San Jose Sharks': 1534,
#   'St. Louis Blues': 1567,
#   'Tampa Bay Lightning': 1699,
#   'Toronto Maple Leafs': 1513,
#   'Vancouver Canucks': 1425,
#   'Vegas Golden Knights': 1531,
#   'Washington Capitals': 1569,
#   'Winnipeg Jets': 1539},
#  '2019-03-28': {'Anaheim Ducks': 1443,
#   'Arizona Coyotes': 1497,
#   'Boston Bruins': 1605,
#   'Buffalo Sabres': 1375,
#   'Calgary Flames': 1555,
#   'Carolina Hurricanes': 1559,
#   'Chicago Blackhawks': 1493,
#   'Colorado Avalanche': 1473,
#   'Columbus Blue Jackets': 1541,
#   'Dallas Stars': 1529,
#   'Detroit Red Wings': 1432,
#   'Edmonton Oilers': 1447,
#   'Florida Panthers': 1468,
#   'Los Angeles Kings': 1408,
#   'Minnesota Wild': 1446,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1516,
#   'New Jersey Devils': 1421,
#   'New York Islanders': 1550,
#   'New York Rangers': 1395,
#   'Ottawa Senators': 1398,
#   'Philadelphia Flyers': 1517,
#   'Pittsburgh Penguins': 1549,
#   'San Jose Sharks': 1522,
#   'St. Louis Blues': 1567,
#   'Tampa Bay Lightning': 1699,
#   'Toronto Maple Leafs': 1513,
#   'Vancouver Canucks': 1435,
#   'Vegas Golden Knights': 1531,
#   'Washington Capitals': 1579,
#   'Winnipeg Jets': 1529},
#  '2019-03-29': {'Anaheim Ducks': 1436,
#   'Arizona Coyotes': 1486,
#   'Boston Bruins': 1605,
#   'Buffalo Sabres': 1375,
#   'Calgary Flames': 1562,
#   'Carolina Hurricanes': 1559,
#   'Chicago Blackhawks': 1493,
#   'Colorado Avalanche': 1484,
#   'Columbus Blue Jackets': 1541,
#   'Dallas Stars': 1529,
#   'Detroit Red Wings': 1442,
#   'Edmonton Oilers': 1447,
#   'Florida Panthers': 1468,
#   'Los Angeles Kings': 1408,
#   'Minnesota Wild': 1458,
#   'Montreal Canadiens': 1508,
#   'Nashville Predators': 1527,
#   'New Jersey Devils': 1411,
#   'New York Islanders': 1550,
#   'New York Rangers': 1410,
#   'Ottawa Senators': 1398,
#   'Philadelphia Flyers': 1517,
#   'Pittsburgh Penguins': 1538,
#   'San Jose Sharks': 1522,
#   'St. Louis Blues': 1552,
#   'Tampa Bay Lightning': 1699,
#   'Toronto Maple Leafs': 1513,
#   'Vancouver Canucks': 1435,
#   'Vegas Golden Knights': 1519,
#   'Washington Capitals': 1579,
#   'Winnipeg Jets': 1529},
#  '2019-03-30': {'Anaheim Ducks': 1446,
#   'Arizona Coyotes': 1486,
#   'Boston Bruins': 1591,
#   'Buffalo Sabres': 1370,
#   'Calgary Flames': 1562,
#   'Carolina Hurricanes': 1568,
#   'Chicago Blackhawks': 1481,
#   'Colorado Avalanche': 1484,
#   'Columbus Blue Jackets': 1551,
#   'Dallas Stars': 1516,
#   'Detroit Red Wings': 1442,
#   'Edmonton Oilers': 1437,
#   'Florida Panthers': 1482,
#   'Los Angeles Kings': 1420,
#   'Minnesota Wild': 1458,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1517,
#   'New Jersey Devils': 1405,
#   'New York Islanders': 1555,
#   'New York Rangers': 1410,
#   'Ottawa Senators': 1411,
#   'Philadelphia Flyers': 1508,
#   'Pittsburgh Penguins': 1538,
#   'San Jose Sharks': 1532,
#   'St. Louis Blues': 1558,
#   'Tampa Bay Lightning': 1686,
#   'Toronto Maple Leafs': 1500,
#   'Vancouver Canucks': 1448,
#   'Vegas Golden Knights': 1509,
#   'Washington Capitals': 1592,
#   'Winnipeg Jets': 1518},
#  '2019-03-31': {'Anaheim Ducks': 1446,
#   'Arizona Coyotes': 1495,
#   'Boston Bruins': 1577,
#   'Buffalo Sabres': 1365,
#   'Calgary Flames': 1571,
#   'Carolina Hurricanes': 1557,
#   'Chicago Blackhawks': 1481,
#   'Colorado Avalanche': 1484,
#   'Columbus Blue Jackets': 1556,
#   'Dallas Stars': 1516,
#   'Detroit Red Wings': 1456,
#   'Edmonton Oilers': 1437,
#   'Florida Panthers': 1482,
#   'Los Angeles Kings': 1420,
#   'Minnesota Wild': 1449,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1517,
#   'New Jersey Devils': 1405,
#   'New York Islanders': 1555,
#   'New York Rangers': 1423,
#   'Ottawa Senators': 1411,
#   'Philadelphia Flyers': 1495,
#   'Pittsburgh Penguins': 1549,
#   'San Jose Sharks': 1523,
#   'St. Louis Blues': 1558,
#   'Tampa Bay Lightning': 1686,
#   'Toronto Maple Leafs': 1500,
#   'Vancouver Canucks': 1448,
#   'Vegas Golden Knights': 1509,
#   'Washington Capitals': 1592,
#   'Winnipeg Jets': 1518},
#  '2019-04-01': {'Anaheim Ducks': 1446,
#   'Arizona Coyotes': 1495,
#   'Boston Bruins': 1577,
#   'Buffalo Sabres': 1365,
#   'Calgary Flames': 1577,
#   'Carolina Hurricanes': 1557,
#   'Chicago Blackhawks': 1472,
#   'Colorado Avalanche': 1476,
#   'Columbus Blue Jackets': 1556,
#   'Dallas Stars': 1516,
#   'Detroit Red Wings': 1456,
#   'Edmonton Oilers': 1429,
#   'Florida Panthers': 1495,
#   'Los Angeles Kings': 1414,
#   'Minnesota Wild': 1449,
#   'Montreal Canadiens': 1519,
#   'Nashville Predators': 1517,
#   'New Jersey Devils': 1416,
#   'New York Islanders': 1543,
#   'New York Rangers': 1412,
#   'Ottawa Senators': 1408,
#   'Philadelphia Flyers': 1495,
#   'Pittsburgh Penguins': 1549,
#   'San Jose Sharks': 1523,
#   'St. Louis Blues': 1566,
#   'Tampa Bay Lightning': 1689,
#   'Toronto Maple Leafs': 1512,
#   'Vancouver Canucks': 1448,
#   'Vegas Golden Knights': 1517,
#   'Washington Capitals': 1579,
#   'Winnipeg Jets': 1527},
#  '2019-04-02': {'Anaheim Ducks': 1446,
#   'Arizona Coyotes': 1483,
#   'Boston Bruins': 1586,
#   'Buffalo Sabres': 1359,
#   'Calgary Flames': 1577,
#   'Carolina Hurricanes': 1566,
#   'Chicago Blackhawks': 1472,
#   'Colorado Avalanche': 1485,
#   'Columbus Blue Jackets': 1547,
#   'Dallas Stars': 1525,
#   'Detroit Red Wings': 1469,
#   'Edmonton Oilers': 1420,
#   'Florida Panthers': 1495,
#   'Los Angeles Kings': 1426,
#   'Minnesota Wild': 1461,
#   'Montreal Canadiens': 1534,
#   'Nashville Predators': 1523,
#   'New Jersey Devils': 1416,
#   'New York Islanders': 1543,
#   'New York Rangers': 1412,
#   'Ottawa Senators': 1408,
#   'Philadelphia Flyers': 1486,
#   'Pittsburgh Penguins': 1536,
#   'San Jose Sharks': 1511,
#   'St. Louis Blues': 1566,
#   'Tampa Bay Lightning': 1674,
#   'Toronto Maple Leafs': 1503,
#   'Vancouver Canucks': 1460,
#   'Vegas Golden Knights': 1517,
#   'Washington Capitals': 1579,
#   'Winnipeg Jets': 1515}}

# %%
# put into a data frame

season = (
    pd.DataFrame(elo_by_date)
    .reset_index()
    .rename(columns={'index':'team'})
)

season.head()
# Out:
#               team  2018-10-03  2018-10-04  2018-10-05  2018-10-06  \
# 0    Anaheim Ducks        1510        1510        1510        1519
# 1  Arizona Coyotes        1500        1490        1490        1481
# 2    Boston Bruins        1490        1500        1500        1500
# 3   Buffalo Sabres        1500        1490        1490        1500
# 4   Calgary Flames        1490        1490        1490        1501
#
#    2018-10-07  2018-10-08  2018-10-09  2018-10-10  2018-10-11  ...  \
# 0        1519        1528        1528        1517        1517  ...
# 1        1481        1481        1481        1492        1492  ...
# 2        1500        1510        1510        1510        1519  ...
# 3        1500        1510        1510        1510        1500  ...
# 4        1501        1501        1512        1512        1501  ...
#
#    2019-03-24  2019-03-25  2019-03-26  2019-03-27  2019-03-28  2019-03-29  \
# 0        1433        1433        1443        1443        1443        1436
# 1        1487        1487        1497        1497        1497        1486
# 2        1608        1600        1600        1605        1605        1605
# 3        1404        1394        1384        1384        1375        1375
# 4        1581        1567        1567        1555        1555        1562
#
#    2019-03-30  2019-03-31  2019-04-01  2019-04-02
# 0        1446        1446        1446        1446
# 1        1486        1495        1495        1483
# 2        1591        1577        1577        1586
# 3        1370        1365        1365        1359
# 4        1562        1571        1577        1577
#
# [5 rows x 174 columns]

# %%
season = pd.melt(
     pd.DataFrame(season),
     id_vars=['team'],
     var_name='date',
     value_name='elo'
)

season.head()
# Great, now have the elo for each time at each day
# Out:
#               team        date   elo
# 0    Anaheim Ducks  2018-10-03  1510
# 1  Arizona Coyotes  2018-10-03  1500
# 2    Boston Bruins  2018-10-03  1490
# 3   Buffalo Sabres  2018-10-03  1500
# 4   Calgary Flames  2018-10-03  1490

# %%
# season['date'] = season['date'].apply(pd.to_datetime)
season['elo_before'] = season.groupby('team')['elo'].shift(1).fillna(1000)
season
# Out:
#                        team        date   elo  elo_before
# 0             Anaheim Ducks  2018-10-03  1510      1000.0
# 1           Arizona Coyotes  2018-10-03  1500      1000.0
# 2             Boston Bruins  2018-10-03  1490      1000.0
# 3            Buffalo Sabres  2018-10-03  1500      1000.0
# 4            Calgary Flames  2018-10-03  1490      1000.0
# 5       Carolina Hurricanes  2018-10-03  1500      1000.0
# 6        Chicago Blackhawks  2018-10-03  1500      1000.0
# 7        Colorado Avalanche  2018-10-03  1500      1000.0
# 8     Columbus Blue Jackets  2018-10-03  1500      1000.0
# 9              Dallas Stars  2018-10-03  1500      1000.0
# 10        Detroit Red Wings  2018-10-03  1500      1000.0
# 11          Edmonton Oilers  2018-10-03  1500      1000.0
# 12         Florida Panthers  2018-10-03  1500      1000.0
# 13        Los Angeles Kings  2018-10-03  1500      1000.0
# 14           Minnesota Wild  2018-10-03  1500      1000.0
# 15       Montreal Canadiens  2018-10-03  1490      1000.0
# 16      Nashville Predators  2018-10-03  1500      1000.0
# 17        New Jersey Devils  2018-10-03  1500      1000.0
# 18       New York Islanders  2018-10-03  1500      1000.0
# 19         New York Rangers  2018-10-03  1500      1000.0
# 20          Ottawa Senators  2018-10-03  1500      1000.0
# 21      Philadelphia Flyers  2018-10-03  1500      1000.0
# 22      Pittsburgh Penguins  2018-10-03  1500      1000.0
# 23          San Jose Sharks  2018-10-03  1490      1000.0
# 24          St. Louis Blues  2018-10-03  1500      1000.0
# 25      Tampa Bay Lightning  2018-10-03  1500      1000.0
# 26      Toronto Maple Leafs  2018-10-03  1510      1000.0
# 27        Vancouver Canucks  2018-10-03  1510      1000.0
# 28     Vegas Golden Knights  2018-10-03  1500      1000.0
# 29      Washington Capitals  2018-10-03  1510      1000.0
# ...                     ...         ...   ...         ...
# 5333        Arizona Coyotes  2019-04-02  1483      1495.0
# 5334          Boston Bruins  2019-04-02  1586      1577.0
# 5335         Buffalo Sabres  2019-04-02  1359      1365.0
# 5336         Calgary Flames  2019-04-02  1577      1577.0
# 5337    Carolina Hurricanes  2019-04-02  1566      1557.0
# 5338     Chicago Blackhawks  2019-04-02  1472      1472.0
# 5339     Colorado Avalanche  2019-04-02  1485      1476.0
# 5340  Columbus Blue Jackets  2019-04-02  1547      1556.0
# 5341           Dallas Stars  2019-04-02  1525      1516.0
# 5342      Detroit Red Wings  2019-04-02  1469      1456.0
# 5343        Edmonton Oilers  2019-04-02  1420      1429.0
# 5344       Florida Panthers  2019-04-02  1495      1495.0
# 5345      Los Angeles Kings  2019-04-02  1426      1414.0
# 5346         Minnesota Wild  2019-04-02  1461      1449.0
# 5347     Montreal Canadiens  2019-04-02  1534      1519.0
# 5348    Nashville Predators  2019-04-02  1523      1517.0
# 5349      New Jersey Devils  2019-04-02  1416      1416.0
# 5350     New York Islanders  2019-04-02  1543      1543.0
# 5351       New York Rangers  2019-04-02  1412      1412.0
# 5352        Ottawa Senators  2019-04-02  1408      1408.0
# 5353    Philadelphia Flyers  2019-04-02  1486      1495.0
# 5354    Pittsburgh Penguins  2019-04-02  1536      1549.0
# 5355        San Jose Sharks  2019-04-02  1511      1523.0
# 5356        St. Louis Blues  2019-04-02  1566      1566.0
# 5357    Tampa Bay Lightning  2019-04-02  1674      1689.0
# 5358    Toronto Maple Leafs  2019-04-02  1503      1512.0
# 5359      Vancouver Canucks  2019-04-02  1460      1448.0
# 5360   Vegas Golden Knights  2019-04-02  1517      1517.0
# 5361    Washington Capitals  2019-04-02  1579      1579.0
# 5362          Winnipeg Jets  2019-04-02  1515      1527.0
#
# [5363 rows x 4 columns]

# %%
df.head(1)
# Out:
#             team        date   elo
# 0  Anaheim Ducks  2018-10-03  1510

# %%
season.head(1)
# Out:
#             team        date   elo
# 0  Anaheim Ducks  2018-10-03  1510

# %% [markdown]
# # Add Later

# %%
# home court advantage
# on average an nba team is favoured by 3.5 points at home, if teams were evenly matched
# FiveThirtyEight: this is approximately 100 elo
# expected_winner = 1 / ( 1 + 10**((loser_elo - (winner_elo+100))/(28*400)))

# %%
# graph this for elo over time between both teams
import altair as alt
alt.renderers.enable('default')

points.query('team == "Toronto Maple Leafs"')
points['date'] = pd.to_datetime(points['date'])
# get the observations for Toronto and Boston
leafs = points[points.team.isin(['Toronto Maple Leafs', 'Boston Bruins'])]

(alt.Chart(leafs)
    .encode(x='date', y='points', color='team')
    .mark_line()
    .properties(background='white', width=700, height=400))
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# Elo strikes a nice balance between ratings systems that account for margin of victory and those that don’t. While teams always gain Elo points after wins and lose Elo points after losses, they gain or lose more with larger margins of victory.
#
# This works by assigning a multiplier to each game based on the final score and dividing it by a team’s projected margin of victory conditional upon having won the game. For instance, the Warriors’ 4-point margin over the Rockets in Game 1 of this year’s Western Conference finals was lower than Elo would expect for a Warriors win. So the Warriors gain Elo points, but not as many as if they’d won by a larger margin. The formula accounts for diminishing returns; going from a 5-point win to a 10-point win matters more than going from a 25-point win to a 30-point win. For the exact formula, see the footnotes.
#
# It accounts for the fact that favourites tend to win by larger margins than they lose them by larger margins. This helps keep elo ratings stable around 1500, and prevent autocorrelation into the rating system (Five Thirty Eight).

# %%
# margin of victory multipler
def mult(winner,loser):
    # score would be in position 1, pull from game
    winner_elo,loser_elo = data[winner][0] , data[loser][0]
    mov = #winning score - #loser score
    mult = (mov + 3)**0.8/(7.5+0.006*(winner_elo-(loser_elo+100)))
    return mult

# add 100 to home elo when calculating prob, and margin of victory
# data[winner][0] + k*(1 - expected_winner)* mult("Toronto","Boston")

# %%
# year to year carry over
# Add elo graphs
# How to add data science? 
* https://en.wikipedia.org/wiki/Brier_score
* Simulate final four with elo
* Calculate the brier score

# %%
# data["Toronto"][0]+20*(1-prob("Toronto","Boston")[0])
